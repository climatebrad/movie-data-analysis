# %%
import locale
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import split_data_fields as sdf

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
#pd.set_option('display.float_format', lambda x: "0:,.2f".format(x))
#locale.setlocale(locale.LC_ALL, '') 

DATA_DIRECTORY = '~/Projects/dc-ds/lectures/dc-ds-100719/module-1/week-3/project/data/'

# %% [markdown]
# ## LOAD DATA

# %%
# IMDB Title Basics
imdb_title_basics_df = pd.read_csv(DATA_DIRECTORY + 'imdb.title.basics.csv.gz')

# %%
# Box Office Mojo
bomojo_df = pd.read_csv(DATA_DIRECTORY + 'bom.movie_gross.csv.gz')

# %%
## Using Brad's cleaned dataframe
top_studios_df = pd.read_csv('imdb_bom_top_studios.csv.gz')
top_studios_df['ct'] = 1
top_studios_df.head()
# Out:
#       tconst           primary_title         original_title  start_year  \
# 0  tt2614684                     '71                    '71        2014
# 1  tt2353767  1,000 Times Good Night  Tusen ganger god natt        2013
# 2  tt1179933     10 Cloverfield Lane    10 Cloverfield Lane        2016
# 3  tt1715873                10 Years               10 Years        2011
# 4  tt3346824              1001 Grams              1001 Gram        2014
#
#    runtime_minutes                 genres  averagerating   numvotes studio  \
# 0            99.00  Action,Drama,Thriller           7.20  46,103.00  RAtt.
# 1           117.00              Drama,War           7.10   6,848.00     FM
# 2           103.00   Drama,Horror,Mystery           7.20 260,383.00   Par.
# 3           100.00   Comedy,Drama,Romance           6.10  22,484.00  Anch.
# 4            93.00                  Drama           6.30   1,301.00     KL
#
#    domestic_gross foreign_gross  year  ct
# 0    1,300,000.00        355000  2015   1
# 1       53,900.00           NaN  2014   1
# 2   72,100,000.00      38100000  2016   1
# 3      203,000.00           NaN  2012   1
# 4       11,000.00           NaN  2015   1

# %%
# convert foreign_gross to a float, must strip all punctuation from the strings first
def strip_punctuation_from_number_string(s, punc="$.,"):
    result = ''
    for char in s:
        if char not in punc:
            result = result + char
    return result
        
bomojo_df['foreign_gross'] = bomojo_df['foreign_gross'].apply(lambda x: strip_punctuation_from_number_string(str(x)))
bomojo_df['foreign_gross'] = bomojo_df['foreign_gross'].astype(float)

# %% [markdown]
# ## Find highest domestic grossing films 2010-2018 in Box Office Mojo Dataset

# %%
# highest foreign grossing films 2010-2018
bomojo_title_millions_df = bomojo_df.groupby(['title']).sum()/1000000
LIST_OF_MOJO_500_GROSSING_MOVIES = list(bomojo_title_millions_df.sort_values('domestic_gross'
                                                                             , ascending=False).head(500).index)
#LIST_OF_MOJO_500_GROSSING_MOVIES
# Out:
# ['Star Wars: The Force Awakens',
#  'Black Panther',
#  'Avengers: Infinity War',
#  'Jurassic World',
#  "Marvel's The Avengers",
#  'Star Wars: The Last Jedi',
#  'Incredibles 2',
#  'Rogue One: A Star Wars Story',
#  'Beauty and the Beast (2017)',
#  'Finding Dory',
#  'Avengers: Age of Ultron',
#  'The Dark Knight Rises',
#  'The Hunger Games: Catching Fire',
#  'Jurassic World: Fallen Kingdom',
#  'Toy Story 3',
#  'Wonder Woman',
#  'Iron Man 3',
#  'Captain America: Civil War',
#  'The Hunger Games',
#  'Jumanji: Welcome to the Jungle',
#  'Frozen',
#  'Guardians of the Galaxy Vol. 2',
#  'Harry Potter and the Deathly Hallows Part 2',
#  'The Secret Life of Pets',
#  'Despicable Me 2',
#  'The Jungle Book (2016)',
#  'Deadpool',
#  'Inside Out',
#  'Furious 7',
#  'Transformers: Dark of the Moon',
#  'American Sniper',
#  'Zootopia',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Minions',
#  'Aquaman',
#  'Spider-Man: Homecoming',
#  'Alice in Wonderland (2010)',
#  'Guardians of the Galaxy',
#  'Batman v Superman: Dawn of Justice',
#  'It',
#  'Suicide Squad',
#  'Deadpool 2',
#  'Thor: Ragnarok',
#  'Iron Man 2',
#  'Skyfall',
#  'The Hobbit: An Unexpected Journey',
#  'The Twilight Saga: Eclipse',
#  'Harry Potter and the Deathly Hallows Part 1',
#  'Inception',
#  'The Twilight Saga: Breaking Dawn Part 2',
#  'Man of Steel',
#  'The Hunger Games: Mockingjay - Part 2',
#  'The Twilight Saga: Breaking Dawn Part 1',
#  'Gravity',
#  "Dr. Seuss' The Grinch (2018)",
#  'Sing',
#  'Monsters University',
#  'Despicable Me 3',
#  'The Amazing Spider-Man',
#  'Captain America: The Winter Soldier',
#  'The Hobbit: The Desolation of Smaug',
#  'The LEGO Movie',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Hangover Part II',
#  'Despicable Me',
#  'Moana',
#  'Transformers: Age of Extinction',
#  'Maleficent',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Fast & Furious 6',
#  'Shrek Forever After',
#  'Brave',
#  'Oz The Great and Powerful',
#  'Fantastic Beasts and Where To Find Them',
#  'X-Men: Days of Future Past',
#  'Doctor Strange',
#  'Justice League',
#  'Star Trek Into Darkness',
#  'The Martian',
#  'Logan (2017)',
#  'The Fate of the Furious',
#  'Big Hero 6',
#  'Mission: Impossible - Fallout',
#  'Ted',
#  'How to Train Your Dragon',
#  'Ant-Man and the Wasp',
#  "Madagascar 3: Europe's Most Wanted",
#  'Bohemian Rhapsody',
#  'A Star is Born (2018)',
#  "Dr. Seuss' The Lorax",
#  'Solo: A Star Wars Story',
#  'Venom (2018)',
#  'Fast Five',
#  'Coco',
#  'Mission: Impossible - Ghost Protocol',
#  'Dawn of the Planet of the Apes',
#  'Thor: The Dark World',
#  'The Amazing Spider-Man 2',
#  'World War Z',
#  'Cinderella (2015)',
#  'Ralph Breaks the Internet',
#  'Tangled',
#  'Godzilla (2014)',
#  'Spectre',
#  'Mission: Impossible - Rogue Nation',
#  '22 Jump Street',
#  'Cars 2',
#  'Teenage Mutant Ninja Turtles (2014)',
#  'Spider-Man: Into The Spider-Verse',
#  'Wreck-It Ralph',
#  'Dunkirk',
#  'Interstellar',
#  'A Quiet Place',
#  'The Croods',
#  'Sherlock Holmes: A Game of Shadows',
#  'Pitch Perfect 2',
#  'The Revenant',
#  'Lincoln',
#  'Thor',
#  'Ant-Man',
#  'MIB 3',
#  'Home (2015)',
#  'How to Train Your Dragon 2',
#  'Rise of the Planet of the Apes',
#  'Captain America: The First Avenger',
#  'The Karate Kid',
#  'Get Out',
#  'The LEGO Batman Movie',
#  'The Boss Baby',
#  'Crazy Rich Asians',
#  'The Greatest Showman',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'Tron Legacy',
#  'Mary Poppins Returns',
#  'True Grit',
#  'The Help',
#  'Hotel Transylvania 2',
#  'Hidden Figures',
#  'Bridesmaids',
#  'Kong: Skull Island',
#  'Gone Girl',
#  'Hotel Transylvania 3: Summer Vacation',
#  'Fifty Shades of Grey',
#  'Kung Fu Panda 2',
#  'Clash of the Titans (2010)',
#  'The SpongeBob Movie: Sponge Out of Water',
#  'Django Unchained',
#  'Jason Bourne',
#  'Grown Ups',
#  'Ice Age: Continental Drift',
#  'Straight Outta Compton',
#  'The Heat',
#  'Fantastic Beasts: The Crimes of Grindelwald',
#  'Halloween (2018)',
#  'Star Trek Beyond',
#  'X-Men: Apocalypse',
#  'Snow White and the Huntsman',
#  'San Andreas',
#  'Trolls',
#  'Mad Max: Fury Road',
#  'Cars 3',
#  'La La Land',
#  'Divergent',
#  "We're the Millers",
#  "Daddy's Home",
#  'Neighbors',
#  'American Hustle',
#  'Puss in Boots',
#  'Les Miserables (2012)',
#  'Megamind',
#  'Little Fockers',
#  'Hotel Transylvania',
#  'War for the Planet of the Apes',
#  'X-Men: First Class',
#  'The Meg',
#  'The Great Gatsby (2013)',
#  'Rio',
#  'Kung Fu Panda 3',
#  'The Smurfs',
#  "Ocean's 8",
#  'Taken 2',
#  '21 Jump Street',
#  'Split',
#  'Ready Player One',
#  'The Conjuring',
#  'Argo',
#  "The King's Speech",
#  'Ride Along',
#  'Identity Thief',
#  'Grown Ups 2',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'The Wolverine',
#  'Wonder',
#  'Silver Linings Playbook',
#  'The Last Airbender',
#  'Rio 2',
#  'The Divergent Series: Insurgent',
#  'Transformers: The Last Knight',
#  'The Peanuts Movie',
#  'Ghostbusters (2016)',
#  'Kingsman: The Secret Service',
#  'Into the Woods',
#  'Shutter Island',
#  'Central Intelligence',
#  'Bumblebee',
#  'Super 8',
#  'Lucy',
#  'The Legend of Tarzan',
#  'Prometheus',
#  'Safe House',
#  'Anchorman 2: The Legend Continues',
#  'Lone Survivor',
#  'Sully',
#  'The Vow',
#  'Life of Pi',
#  'The Fault in our Stars',
#  'Rango',
#  'The Good Dinosaur',
#  'G.I. Joe: Retaliation',
#  'Mamma Mia! Here We Go Again',
#  'Cloudy with a Chance of Meatballs 2',
#  'The Other Guys',
#  'Salt',
#  'Now You See Me',
#  'Horrible Bosses',
#  'The Nun',
#  'Jackass 3-D',
#  'The Wolf of Wall Street',
#  'Green Lantern',
#  "Lee Daniels' The Butler",
#  'Creed II',
#  'Unbroken',
#  'Peter Rabbit',
#  'Girls Trip',
#  'Fifty Shades Darker',
#  'Magic Mike',
#  'Night at the Museum: Secret of the Tomb',
#  'Bad Moms',
#  'The Bourne Legacy',
#  'The Hangover Part III',
#  'Mr. Peabody & Sherman',
#  'Spy',
#  "Valentine's Day",
#  'Trainwreck',
#  'Creed',
#  'Hop',
#  'Baby Driver',
#  'Epic',
#  'The Angry Birds Movie',
#  'Captain Phillips',
#  'Black Swan',
#  '300: Rise of An Empire',
#  'Robin Hood',
#  'Pitch Perfect 3',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'Paranormal Activity 3',
#  "Daddy's Home 2",
#  'Journey 2: The Mysterious Island',
#  'The Mule',
#  'Rise of the Guardians',
#  'The Expendables',
#  'Independence Day: Resurgence',
#  'Just Go With It',
#  'Murder on the Orient Express (2017)',
#  'The Girl with the Dragon Tattoo (2011)',
#  'The Conjuring 2',
#  'The Maze Runner',
#  'The Equalizer 2',
#  'Annabelle: Creation',
#  'Jackass Presents: Bad Grandpa',
#  'Pacific Rim',
#  'The Equalizer',
#  'This is the End',
#  'Noah',
#  'Rampage (2018)',
#  'A Wrinkle in Time',
#  'Due Date',
#  'Arrival',
#  'Fifty Shades Freed',
#  'Bad Teacher',
#  'Edge of Tomorrow',
#  'Kingsman: The Golden Circle',
#  'Cowboys & Aliens',
#  'Yogi Bear',
#  'Gnomeo and Juliet',
#  'Passengers (2016)',
#  "Disney's Christopher Robin",
#  'Olympus Has Fallen',
#  'The Green Hornet',
#  'Date Night',
#  'Sausage Party',
#  'The Social Network',
#  'Zero Dark Thirty',
#  'Sex and the City 2',
#  'The Book of Eli',
#  'The Lion King (in 3D)',
#  'Flight',
#  'The Fighter',
#  'The Magnificent Seven (2016)',
#  'Tomorrowland',
#  'Elysium',
#  'Non-Stop',
#  'The Town',
#  'Blade Runner 2049',
#  'John Wick: Chapter Two',
#  'Think Like a Man',
#  'Heaven is for Real',
#  'Ride Along 2',
#  'The Imitation Game',
#  'Prince of Persia: The Sands of Time',
#  'Red',
#  'Get Hard',
#  'Planes',
#  'Terminator: Genisys',
#  'Taken 3',
#  'The Lone Ranger',
#  "Don't Breathe",
#  'Oblivion',
#  'Percy Jackson & The Olympians: The Lightning Thief',
#  'The Muppets',
#  "Miss Peregrine's Home for Peculiar Children",
#  'Sisters',
#  'The Campaign',
#  'The Accountant',
#  'Dumb and Dumber To',
#  'The Emoji Movie',
#  'Annie (2014)',
#  'Alvin and the Chipmunks: The Road Chip',
#  'Fury (2014)',
#  'Real Steel',
#  'Power Rangers (2017)',
#  'Green Book',
#  'The Expendables 2',
#  'Paranormal Activity 2',
#  'Tammy',
#  'Ferdinand',
#  'Crazy, Stupid, Love.',
#  'Annabelle',
#  'The Other Woman (2014)',
#  'Wrath of the Titans',
#  'Insidious Chapter 2',
#  'Battle: Los Angeles',
#  'Immortals',
#  'Penguins of Madagascar',
#  'Saving Mr. Banks',
#  'Smallfoot',
#  'Turbo',
#  'The Descendants',
#  "Let's Be Cops",
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'The Post',
#  'Maze Runner: The Scorch Trials',
#  'Unstoppable',
#  'Ted 2',
#  'Eat Pray Love',
#  'Zookeeper',
#  'The Mummy (2017)',
#  'Jack Reacher',
#  'Goosebumps',
#  'Dear John',
#  'War Horse',
#  'Dark Shadows',
#  'The Purge: Election Year',
#  'Limitless',
#  'Pixels',
#  'Tower Heist',
#  'The Monuments Men',
#  'The Adventures of Tintin',
#  'Parental Guidance',
#  'Night School (2018)',
#  'The A-Team',
#  'Alice Through the Looking Glass',
#  'Knight & Day',
#  'Paddington',
#  "Pete's Dragon (2016)",
#  'The Intern',
#  'Contagion',
#  'We Bought a Zoo',
#  'Moneyball',
#  '2 Guns',
#  "The Hitman's Bodyguard",
#  'The Girl on the Train (2016)',
#  'Alien: Covenant',
#  'Jack and Jill',
#  'Captain Underpants: The First Epic Movie',
#  'Hugo',
#  'Boo! A Madea Halloween',
#  'John Carter',
#  'White House Down',
#  'Justin Bieber: Never Say Never',
#  'Dinner for Schmucks',
#  'Storks',
#  'Hercules (2014)',
#  'Bridge of Spies',
#  'Dolphin Tale',
#  '10 Cloverfield Lane',
#  'A Bad Moms Christmas',
#  'The Purge: Anarchy',
#  'Mama',
#  'Safe Haven',
#  'The Smurfs 2',
#  'Paul Blart: Mall Cop 2',
#  'No Strings Attached',
#  'The Best Man Holiday',
#  'The Big Short',
#  'Act of Valor',
#  'The First Purge',
#  'Game Night',
#  'Percy Jackson: Sea of Monsters',
#  'Book Club',
#  'The House With A Clock In Its Walls',
#  'Skyscraper',
#  "Mr. Popper's Penguins",
#  'War Room',
#  'Insidious: The Last Key',
#  'The Tourist',
#  'This Is 40',
#  'Instant Family',
#  'A Good Day to Die Hard',
#  'Lights Out',
#  'Hacksaw Ridge',
#  'The Bounty Hunter',
#  'Alexander and the Terrible, Horrible, No Good, Very Bad Day',
#  'Looper',
#  'Contraband',
#  'Warm Bodies',
#  'The Divergent Series: Allegiant',
#  'Magic Mike XXL',
#  "Tyler Perry's Madea's Witness Protection",
#  'Battleship',
#  'Think Like a Man Too',
#  'Jack the Giant Slayer',
#  'The Visit',
#  'Now You See Me 2',
#  'Exodus: Gods and Kings',
#  'Pitch Perfect',
#  'Mirror Mirror',
#  'Chronicle (2012)',
#  "A Dog's Purpose",
#  'The Wedding Ringer',
#  'The Purge',
#  'The Nut Job',
#  'Ice Age: Collision Course',
#  'Happy Feet Two',
#  'Diary of a Wimpy Kid',
#  'Last Vegas',
#  'The Shape of Water',
#  'Unknown',
#  'Hope Springs',
#  'The Boss',
#  "The Sorcerer's Apprentice",
#  'A Nightmare on Elm Street (2010)',
#  'The Last Song',
#  'Black Mass',
#  'The Adjustment Bureau',
#  'London Has Fallen',
#  'Underworld Awakening',
#  'The Wolfman',
#  "Ender's Game",
#  'Miracles from Heaven',
#  'Deepwater Horizon',
#  'Prisoners',
#  'Get Him to the Greek',
#  "God's Not Dead",
#  'The Lucky One',
#  'After Earth',
#  'Blockers',
#  'Why Him?',
#  "Tyler Perry's Why Did I Get Married Too?",
#  'Resident Evil: Afterlife',
#  'Tooth Fairy',
#  'Pacific Rim Uprising',
#  'The Dictator',
#  'Son of God',
#  'Secretariat',
#  'My Big Fat Greek Wedding 2',
#  'The LEGO Ninjago Movie',
#  'The Grand Budapest Hotel',
#  'Planes: Fire & Rescue',
#  'Total Recall (2012)',
#  'Vacation',
#  'Jack Reacher: Never Go Back',
#  'Water for Elephants',
#  'RoboCop (2014)',
#  'Easy A',
#  'Tomb Raider',
#  'The Secret Life of Walter Mitty',
#  'Baywatch',
#  'The Lincoln Lawyer',
#  'Maze Runner: The Death Cure',
#  'Titanic 3D',
#  'Fences',
#  'Takers',
#  'The Shack',
#  'The Perfect Guy',
#  'American Reunion',
#  'Escape From Planet Earth',
#  'Midnight in Paris',
#  '12 Years a Slave',
#  'Darkest Hour']

# %%
## Return a dataframe of the IMDB dataset for just the top 500 domestic grossing movies according to MOJO

# %%
top500 = imdb_title_basics_df[imdb_title_basics_df.primary_title.isin(LIST_OF_MOJO_500_GROSSING_MOVIES)]
#top500
# Out:
#            tconst                        primary_title  \
# 54      tt0359950      The Secret Life of Walter Mitty
# 60      tt0369610                       Jurassic World
# 61      tt0372538                                  Spy
# 71      tt0398286                              Tangled
# 73      tt0401729                          John Carter
# 81      tt0409847                     Cowboys & Aliens
# 92      tt0427152                  Dinner for Schmucks
# 95      tt0429493                           The A-Team
# 99      tt0433035                           Real Steel
# 104     tt0435761                          Toy Story 3
# 115     tt0443272                              Lincoln
# 126     tt0448694                        Puss in Boots
# 131     tt0451279                         Wonder Woman
# 136     tt0454876                           Life of Pi
# 139     tt0455944                        The Equalizer
# 141     tt0458339   Captain America: The First Avenger
# 172     tt0471042                          Tower Heist
# 173     tt0472181                           The Smurfs
# 176     tt0473075  Prince of Persia: The Sands of Time
# 185     tt0477080                          Unstoppable
# 190     tt0478970                              Ant-Man
# 199     tt0481499                           The Croods
# 246     tt0770828                         Man of Steel
# 258     tt0780653                          The Wolfman
# 269     tt0790724                         Jack Reacher
# 281     tt0800369                                 Thor
# 287     tt0804509                             The Mule
# 292     tt0808510                          Tooth Fairy
# 297     tt0810913                        Jack and Jill
# 311     tt0816692                         Interstellar
# ...           ...                                  ...
# 115582  tt6857166                            Book Club
# 115642  tt6858500                           Robin Hood
# 116348  tt6911608          Mamma Mia! Here We Go Again
# 117014  tt6966692                           Green Book
# 117464  tt7002100                                 Coco
# 118519  tt7098772                          Unstoppable
# 121497  tt7325124                              Arrival
# 121517  tt7326798                              Sisters
# 122460  tt7401588                       Instant Family
# 123507  tt7496196                                 Hugo
# 123719  tt7514806                                 Mama
# 126503  tt7728220                         Tomorrowland
# 128522  tt7906260                          Tooth Fairy
# 129149  tt7959026                             The Mule
# 132362  tt8269544                           Inside Out
# 132873  tt8323598                                 Mama
# 133274  tt8358722                                Brave
# 135285  tt8558276                           Robin Hood
# 136257  tt8672656                             Get Hard
# 137636  tt8826828                             Oblivion
# 137852  tt8851190                                  Red
# 139807  tt9048972                              Sisters
# 141374  tt9225192                          Unstoppable
# 142543  tt9386300                            Neighbors
# 142617  tt9392532                            Neighbors
# 143266  tt9499562                          Unstoppable
# 144711  tt9702034                            Neighbors
# 144725  tt9703646                       Into the Woods
# 145664  tt9851050                              Sisters
# 146078  tt9906218                          Unstoppable
#
#                              original_title  start_year  runtime_minutes  \
# 54          The Secret Life of Walter Mitty        2013           114.00
# 60                           Jurassic World        2015           124.00
# 61                                      Spy        2011           110.00
# 71                                  Tangled        2010           100.00
# 73                              John Carter        2012           132.00
# 81                         Cowboys & Aliens        2011           119.00
# 92                      Dinner for Schmucks        2010           114.00
# 95                               The A-Team        2010           117.00
# 99                               Real Steel        2011           127.00
# 104                             Toy Story 3        2010           103.00
# 115                                 Lincoln        2012           150.00
# 126                           Puss in Boots        2011            90.00
# 131                            Wonder Woman        2017           141.00
# 136                              Life of Pi        2012           127.00
# 139                           The Equalizer        2014           132.00
# 141      Captain America: The First Avenger        2011           124.00
# 172                             Tower Heist        2011           104.00
# 173                              The Smurfs        2011           103.00
# 176     Prince of Persia: The Sands of Time        2010           116.00
# 185                             Unstoppable        2010            98.00
# 190                                 Ant-Man        2015           117.00
# 199                              The Croods        2013            98.00
# 246                            Man of Steel        2013           143.00
# 258                             The Wolfman        2010           103.00
# 269                            Jack Reacher        2012           130.00
# 281                                    Thor        2011           115.00
# 287                                 La mula        2013           100.00
# 292                             Tooth Fairy        2010           101.00
# 297                           Jack and Jill        2011            91.00
# 311                            Interstellar        2014           169.00
# ...                                     ...         ...              ...
# 115582                            Book Club        2018           104.00
# 115642                           Robin Hood        2018              nan
# 116348          Mamma Mia! Here We Go Again        2018           114.00
# 117014                           Green Book        2018           130.00
# 117464                                 Coco        2017            98.00
# 118519                          Unstoppable        2017            12.00
# 121497                              Arrival        2012              nan
# 121517                              Sisters        2018              nan
# 122460                       Instant Family        2018           118.00
# 123507                                 Hugo        2017            80.00
# 123719                                 Mama        2017            89.00
# 126503                         Tomorrowland        2017            70.00
# 128522                                 Toof        2019            86.00
# 129149                             The Mule        2018           116.00
# 132362                           Inside Out        2018              nan
# 132873                                 Mama        2017              nan
# 133274                                Brave        2014              nan
# 135285                           Robin Hood        2017            60.00
# 136257                             Get Hard        2018            90.00
# 137636                             Oblivion        2018              nan
# 137852                                  Red        2018            90.00
# 139807                              Sisters        2018            72.00
# 141374                     Seongnan hwangso        2018           116.00
# 142543                            Neighbors        2018            74.00
# 142617                            Neighbors        2018            90.00
# 143266                          Unstoppable        2017            52.00
# 144711                            Neighbors        2012              nan
# 144725                       Into the Woods        2018              nan
# 145664                              Sisters        2019              nan
# 146078                          Unstoppable        2019            84.00
#
#                               genres
# 54            Adventure,Comedy,Drama
# 60           Action,Adventure,Sci-Fi
# 61                Action,Crime,Drama
# 71        Adventure,Animation,Comedy
# 73           Action,Adventure,Sci-Fi
# 81            Action,Sci-Fi,Thriller
# 92                            Comedy
# 95         Action,Adventure,Thriller
# 99               Action,Drama,Family
# 104       Adventure,Animation,Comedy
# 115          Biography,Drama,History
# 126       Action,Adventure,Animation
# 131         Action,Adventure,Fantasy
# 136          Adventure,Drama,Fantasy
# 139            Action,Crime,Thriller
# 141          Action,Adventure,Sci-Fi
# 172              Action,Comedy,Crime
# 173       Adventure,Animation,Comedy
# 176         Action,Adventure,Fantasy
# 185                  Action,Thriller
# 190          Action,Adventure,Comedy
# 199       Action,Adventure,Animation
# 246          Action,Adventure,Sci-Fi
# 258             Drama,Fantasy,Horror
# 269            Action,Crime,Thriller
# 281         Action,Adventure,Fantasy
# 287                     Comedy,Drama
# 292            Comedy,Family,Fantasy
# 297                           Comedy
# 311           Adventure,Drama,Sci-Fi
# ...                              ...
# 115582          Comedy,Drama,Romance
# 115642                           NaN
# 116348        Comedy,Musical,Romance
# 117014        Biography,Comedy,Drama
# 117464                        Horror
# 118519                   Documentary
# 121497                   Documentary
# 121517                        Comedy
# 122460                  Comedy,Drama
# 123507                   Documentary
# 123719                   Documentary
# 126503                   Documentary
# 128522                        Horror
# 129149          Crime,Drama,Thriller
# 132362                           NaN
# 132873                         Drama
# 133274                         Drama
# 135285      Action,Adventure,History
# 136257                        Comedy
# 137636                           NaN
# 137852                         Drama
# 139807  Biography,Comedy,Documentary
# 141374                  Action,Crime
# 142543                   Documentary
# 142617                  Comedy,Drama
# 143266                   Documentary
# 144711                         Drama
# 144725                Fantasy,Horror
# 145664                  Action,Drama
# 146078                   Documentary
#
# [534 rows x 6 columns]

# %%
# Duplicated movies within Top 500
top500[top500.duplicated(subset='primary_title', keep=False)].sort_values('primary_title')
# Out:
#             tconst  primary_title                    original_title  \
# 113035   tt6644200  A Quiet Place                     A Quiet Place
# 108191   tt6347308  A Quiet Place                     A Quiet Place
# 121497   tt7325124        Arrival                           Arrival
# 42473    tt2543164        Arrival                           Arrival
# 82234    tt4727712      Book Club                         Book Club
# 115582   tt6857166      Book Club                         Book Club
# 133274   tt8358722          Brave                             Brave
# 5935     tt1217209          Brave                             Brave
# 38424    tt2380307           Coco                              Coco
# 5231    tt10453328           Coco                              Coco
# 117464   tt7002100           Coco                              Coco
# 51886    tt3076658          Creed                             Creed
# 11494    tt1632705          Creed                             Creed
# 76188    tt4354930          Creed                             Creed
# 11037    tt1617630   Daddy's Home                      Daddy's Home
# 8818     tt1528854   Daddy's Home                      Daddy's Home
# 69399    tt3958034  Don't Breathe                     Don't Breathe
# 72971    tt4160708  Don't Breathe                     Don't Breathe
# 8936     tt1535108        Elysium                           Elysium
# 17339    tt1783264        Elysium                           Elysium
# 54364    tt3197696         Fences                            Fences
# 45073    tt2671706         Fences                            Fences
# 76735    tt4389440         Flight                            Flight
# 22051    tt1907668         Flight                            Flight
# 10824    tt1611845         Frozen               Wai nei chung ching
# 6647     tt1323045         Frozen                            Frozen
# 35107    tt2294629         Frozen                            Frozen
# 37312    tt2355597     Game Night                        Game Night
# 45425    tt2704998     Game Night                        Game Night
# 42886    tt2561572       Get Hard                          Get Hard
# ...            ...            ...                               ...
# 56434    tt3300078   The Revenant                      The Revenant
# 12455    tt1663202   The Revenant                      The Revenant
# 341      tt0840361       The Town                          The Town
# 106885   tt6259458       The Town                          The Town
# 33628    tt2252032      The Visit                         The Visit
# 21952    tt1901018      The Visit                         The Visit
# 10642    tt1605776      The Visit                         The Visit
# 61859    tt3567288      The Visit                         The Visit
# 23714    tt1964418   Tomorrowland                      Tomorrowland
# 126503   tt7728220   Tomorrowland                      Tomorrowland
# 292      tt0808510    Tooth Fairy                       Tooth Fairy
# 128522   tt7906260    Tooth Fairy                              Toof
# 4297    tt10402572       Unbroken                          Unbroken
# 18375    tt1809398       Unbroken                          Unbroken
# 100549   tt5877156        Unknown                           Unknown
# 7274     tt1401152        Unknown                           Unknown
# 39363    tt2402731        Unknown                           Unknown
# 90136    tt5213284        Unknown                           Unknown
# 141374   tt9225192    Unstoppable                  Seongnan hwangso
# 185      tt0477080    Unstoppable                       Unstoppable
# 143266   tt9499562    Unstoppable                       Unstoppable
# 146078   tt9906218    Unstoppable                       Unstoppable
# 118519   tt7098772    Unstoppable                       Unstoppable
# 49677    tt2951338    Unstoppable                       Unstoppable
# 51775    tt3070502    Unstoppable                       Unstoppable
# 56700    tt3313072      War Horse  National Theatre Live: War Horse
# 9673     tt1568911      War Horse                         War Horse
# 70470    tt4028068   Wonder Woman                      Wonder Woman
# 131      tt0451279   Wonder Woman                      Wonder Woman
# 75016    tt4283448   Wonder Woman                      Wonder Woman
#
#         start_year  runtime_minutes                         genres
# 113035        2018            90.00            Drama,Horror,Sci-Fi
# 108191        2016            80.00                    Documentary
# 121497        2012              nan                    Documentary
# 42473         2016           116.00           Drama,Mystery,Sci-Fi
# 82234         2015            72.00                    Documentary
# 115582        2018           104.00           Comedy,Drama,Romance
# 133274        2014              nan                          Drama
# 5935          2012            93.00     Adventure,Animation,Comedy
# 38424         2017           105.00     Adventure,Animation,Comedy
# 5231          2018              nan                            NaN
# 117464        2017            98.00                         Horror
# 51886         2015           133.00                    Drama,Sport
# 11494         2010            77.00                         Horror
# 76188         2016            80.00                    Crime,Drama
# 11037         2010            90.00                 Drama,Thriller
# 8818          2015            96.00                         Comedy
# 69399         2014            86.00                    Documentary
# 72971         2016            88.00          Crime,Horror,Thriller
# 8936          2013           109.00            Action,Drama,Sci-Fi
# 17339         2010              nan                          Drama
# 54364         2013           117.00                   Drama,Family
# 45073         2016           139.00                          Drama
# 76735         2017              nan                            NaN
# 22051         2012           138.00                 Drama,Thriller
# 10824         2010            92.00                Fantasy,Romance
# 6647          2010            93.00          Adventure,Drama,Sport
# 35107         2013           102.00     Adventure,Animation,Comedy
# 37312         2012              nan                         Comedy
# 45425         2018           100.00            Action,Comedy,Crime
# 42886         2015           100.00                   Comedy,Crime
# ...            ...              ...                            ...
# 56434         2012            80.00                         Horror
# 12455         2015           156.00     Action,Adventure,Biography
# 341           2010           125.00           Crime,Drama,Thriller
# 106885        2012           101.00                         Horror
# 33628         2012            52.00              Documentary,Drama
# 21952         2010            50.00                       Thriller
# 10642         2010            90.00           Comedy,Drama,Romance
# 61859         2015            94.00        Horror,Mystery,Thriller
# 23714         2015           130.00        Action,Adventure,Family
# 126503        2017            70.00                    Documentary
# 292           2010           101.00          Comedy,Family,Fantasy
# 128522        2019            86.00                         Horror
# 4297          2018           104.00                          Drama
# 18375         2014           137.00          Biography,Drama,Sport
# 100549        2017              nan                            NaN
# 7274          2011           113.00        Action,Mystery,Thriller
# 39363         2012            96.00                          Drama
# 90136         2015              nan                            NaN
# 141374        2018           116.00                   Action,Crime
# 185           2010            98.00                Action,Thriller
# 143266        2017            52.00                    Documentary
# 146078        2019            84.00                    Documentary
# 118519        2017            12.00                    Documentary
# 49677         2015            53.00  Biography,Documentary,History
# 51775         2013            65.00                    Documentary
# 56700         2014              nan                          Drama
# 9673          2011           146.00              Drama,History,War
# 70470         2014            60.00                         Sci-Fi
# 131           2017           141.00       Action,Adventure,Fantasy
# 75016         2016            75.00        Documentary,Drama,Sport
#
# [165 rows x 6 columns]

# %% [markdown]
# ## Genre Analysis

# %%
## IGNORE this stuff--- not used

genres_counts = top_studios_df.groupby('genres').count().sort_values(ascending=False,by='tconst')['tconst']
genres_list = [str(x).split(",") for x in top_studios_df.genres]
#len(genres_list)
#len(top_studios_df)
#top_studios_df['genres_list'] = [str(x).split(",") for x in top_studios_df.genres

# %%
# THIS USES THE CLEANED DATASET
genres_list = [str(x).split(",") for x in top_studios_df.genres.dropna()]
#genres_list = [x for x in genres_list]
flatten_genres = list(set([val for sublist in genres_list for val in sublist]))
print("There are" , len(flatten_genres), "unique genres in the IMDB dataset\n", flatten_genres)
# Out:
# There are 21 unique genres in the IMDB dataset
#  ['Sci-Fi', 'Animation', 'Mystery', 'War', 'Horror', 'Crime', 'Western', 'Documentary', 'Drama', 'Action', 'Comedy', 'Thriller', 'Family', 'Fantasy', 'Musical', 'Adventure', 'Sport', 'Music', 'Biography', 'Romance', 'History']

# %%
top500_genres_list = [str(x).split(",") for x in top500.genres.dropna()]
#genres_list = [x for x in genres_list]
top500_flatten_genres = list(set([val for sublist in top500_genres_list for val in sublist]))
print("There are" , len(top500_flatten_genres), "unique genres in the Top 500 grossing dataset\n", top500_flatten_genres, "\n")
# Out:
# There are 21 unique genres in the Top 500 grossing dataset
#  ['Sci-Fi', 'Animation', 'Mystery', 'War', 'Horror', 'Crime', 'Western', 'Documentary', 'Drama', 'Action', 'Comedy', 'Thriller', 'Family', 'Fantasy', 'Musical', 'Adventure', 'Sport', 'Music', 'Biography', 'Romance', 'History']

# %%
# List of genres to ignore
[x for x in flatten_genres if x not in top500_flatten_genres]
# Out:
# ['News', 'Talk-Show', 'Game-Show', 'Adult', 'Reality-TV', 'Short']

# %%
top500_grouped = top500.groupby('genres')#.count().sort_values(by='tconst', ascending=False)
#top500_grouped.filter(lambda x: x['tconst'].count() > 1).sort_values('genres')

# %%
df_grouped_genre = top_studios_df.groupby('genres').sum().sort_values(ascending=False, by='domestic_gross').head()

# %% [markdown]
# ## Genre Visualizations

# %%
# Top 20 Highest Domestic Grossing Genres produced by studios with total domestic gross > $1M
top_studios_df.groupby('genres').sum().sort_values(ascending=False, 
                                                   by='domestic_gross')['domestic_gross'][:20].plot.bar();

# %%
top20_grossing_genres = top_studios_df.groupby('genres').sum() \
                              .sort_values(ascending=False, by='domestic_gross')[['domestic_gross','ct']][:20]
top20_grossing_genres.plot.bar()

# %% [markdown]
# ## Domestic gross and movie counts on the same plot

# %%
df = top20_grossing_genres
fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df.domestic_gross.plot(kind='bar', color='red', ax=ax, width=width, position=1)
df.ct.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

# %% [markdown]
# ## Average domestic gross per title

# %%
(df.domestic_gross / df.ct).sort_values().plot.bar()

# %%
top20_counts_df = top_studios_df[top_studios_df.genres.isin(top20_grossing_genres)].groupby('genres').count().sort_values(ascending=False, by='tconst')

# %%
#top20_counts_df.plot.bar()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)

# %%
#long_df.genre.value_counts().plot.bar();

# %% [markdown]
# ## Merge 'The Numbers' data set with our studio data

# %%
tn_df = pd.read_csv(DATA_DIRECTORY + 'tn.movie_budgets.csv.gz')
tn_df['ct']=1
tn_df['release_year'] = pd.to_datetime(tn_df.release_date).dt.year
tn_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  ct  release_year
# 0      $425,000,000   $760,507,625  $2,776,345,279   1          2009
# 1      $410,600,000   $241,063,875  $1,045,663,875   1          2011
# 2      $350,000,000    $42,762,350    $149,762,350   1          2019
# 3      $330,600,000   $459,005,868  $1,403,013,963   1          2015
# 4      $317,000,000   $620,181,382  $1,316,721,747   1          2017

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 8 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# ct                   5782 non-null int64
# release_year         5782 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 361.5+ KB

# %%
# Remove duplicate titles from TN dataset, taking the title with the latest release year
tn_df_dedup = tn_df[tn_df['release_year'] == tn_df.groupby(['movie'])['release_year'].transform(max)]
tn_df_dedup.head()
tn_df.groupby(['movie'])['release_year'].transform(max)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  ct  release_year
# 0      $425,000,000   $760,507,625  $2,776,345,279   1          2009
# 1      $410,600,000   $241,063,875  $1,045,663,875   1          2011
# 2      $350,000,000    $42,762,350    $149,762,350   1          2019
# 3      $330,600,000   $459,005,868  $1,403,013,963   1          2015
# 4      $317,000,000   $620,181,382  $1,316,721,747   1          2017

# %%
df.groupby(['movie'])['release_year'].transform(max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8e70d895efba> in <module>
# ----> 1 df.groupby(['movie'])['release_year'].transform(max)
#
# NameError: name 'df' is not defined

# %%
top_studios_df.shape
# Out:
# (2440, 13)

# %%
tn_cols = ['movie','release_date', 'production_budget', 'domestic_gross', 'worldwide_gross']
top_studios_df_and_tn = top_studios_df.merge(tn_df_dedup[tn_cols], how="inner", left_on='primary_title', right_on='movie')
top_studios_df_and_tn.shape
# Out:
# (1148, 18)

# %%
tn_cols = ['movie','release_date', 'production_budget', 'domestic_gross', 'worldwide_gross']
top_studios_df_and_tn = top_studios_df.merge(tn_df_dedup[tn_cols], how="inner", left_on='primary_title', right_on='movie')

# %%
tn_df_dedup[tn_df_dedup.movie.str.contains('Star Wars')]
# Out:
#       id  release_date                                     movie  \
# 4      5  Dec 15, 2017         Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015      Star Wars Ep. VII: The Force Awakens
# 11    12  May 25, 2018                   Solo: A Star Wars Story
# 44    45  Dec 16, 2016              Rogue One: A Star Wars Story
# 303    4  May 19, 1999       Star Wars Ep. I: The Phantom Menace
# 304    5  May 19, 2005    Star Wars Ep. III: Revenge of the Sith
# 305    6  May 16, 2002    Star Wars Ep. II: Attack of the Clones
# 1783  84  May 25, 1983      Star Wars Ep. VI: Return of the Jedi
# 2367  68  May 21, 1980  Star Wars Ep. V: The Empire Strikes Back
# 3464  65  May 25, 1977              Star Wars Ep. IV: A New Hope
# 3831  32  Aug 15, 2008                 Star Wars: The Clone Wars
#
#      production_budget domestic_gross worldwide_gross  ct  release_year
# 4         $317,000,000   $620,181,382  $1,316,721,747   1          2017
# 5         $306,000,000   $936,662,225  $2,053,311,220   1          2015
# 11        $275,000,000   $213,767,512    $393,151,347   1          2018
# 44        $200,000,000   $532,177,324  $1,049,102,856   1          2016
# 303       $115,000,000   $474,544,677  $1,027,044,677   1          1999
# 304       $115,000,000   $380,270,577    $848,998,877   1          2005
# 305       $115,000,000   $310,676,740    $656,695,615   1          2002
# 1783       $32,500,000   $309,205,079    $572,705,079   1          1983
# 2367       $23,000,000   $290,271,960    $534,161,334   1          1980
# 3464       $11,000,000   $460,998,007    $786,598,007   1          1977
# 3831        $8,500,000    $35,161,554     $68,695,443   1          2008

# %% [markdown]
# ## Joining to TN dropped roughly 1200 titles
# - This is due to slight variations in punctuation or use of numbers in the title.
# - As a result some top grossing movies were dropped, including The last jedi, Guardians of the Galaxy.
# - The full list of dropped movies is shown below

# %%
top_studios_df[top_studios_df.primary_title.str.contains('Star Wars')]
# Out:
#          tconst                 primary_title  \
# 1507  tt3748528  Rogue One: A Star Wars Story
# 1622  tt3778644       Solo: A Star Wars Story
# 1653  tt2527336      Star Wars: The Last Jedi
#
#                                original_title  start_year  runtime_minutes  \
# 1507                                Rogue One        2016           133.00
# 1622                  Solo: A Star Wars Story        2018           135.00
# 1653  Star Wars: Episode VIII - The Last Jedi        2017           152.00
#
#                         genres  averagerating   numvotes studio  \
# 1507   Action,Adventure,Sci-Fi           7.80 478,592.00     BV
# 1622  Action,Adventure,Fantasy           7.00 226,243.00     BV
# 1653  Action,Adventure,Fantasy           7.10 462,903.00     BV
#
#       domestic_gross foreign_gross  year  ct
# 1507  532,200,000.00     523900000  2016   1
# 1622  213,800,000.00     179200000  2018   1
# 1653  620,200,000.00     712400000  2017   1

# %%
# Titles from our project dataset that got dropped when joining with TN dataset on title
top_studios_df[~top_studios_df.primary_title.isin(top_studios_df_and_tn.movie)].sort_values('numvotes', ascending=False)
# Out:
#          tconst                            primary_title  \
# 1981  tt1504320                        The King's Speech
# 765   tt3896198           Guardians of the Galaxy Vol. 2
# 1653  tt2527336                 Star Wars: The Last Jedi
# 462   tt1570728                     Crazy, Stupid, Love.
# 1217  tt1229238     Mission: Impossible - Ghost Protocol
# 628   tt1905041                         Fast & Furious 6
# 1542  tt0446029              Scott Pilgrim vs. the World
# 1218  tt2381249       Mission: Impossible - Rogue Nation
# 1928  tt1951261                    The Hangover Part III
# 1439  tt0473075      Prince of Persia: The Sands of Time
# 1952  tt2106476                                 The Hunt
# 1216  tt4912910            Mission: Impossible - Fallout
# 1435  tt2397535                           Predestination
# 855   tt1464540                         I Am Number Four
# 1647  tt3079380                                      Spy
# 84    tt1832382                             A Separation
# 460   tt0409847                         Cowboys & Aliens
# 1822  tt3065204                          The Conjuring 2
# 545   tt4160708                            Don't Breathe
# 2104  tt1899353                     The Raid: Redemption
# 404   tt2883512                                     Chef
# 2389  tt5362988                               Wind River
# 193   tt2094766                         Assassin's Creed
# 1937  tt1959563                   The Hitman's Bodyguard
# 71    tt2557490        A Million Ways to Die in the West
# 369   tt3553976                        Captain Fantastic
# 358   tt5726616                     Call Me by Your Name
# 2384  tt3011894                               Wild Tales
# 1830  tt0810819                          The Danish Girl
# 593   tt2316411                                    Enemy
# ...         ...                                      ...
# 1263  tt2053397                                    Muran
# 1038  tt4296800                                 Ladrones
# 341   tt6152908                         Buddies in India
# 850   tt2407826                          Husbands in Goa
# 1060  tt1464251                                  Leaving
# 550   tt2309048                           Double Trouble
# 1979  tt6817202                     The King's Case Note
# 982   tt5595240                                  Kaptaan
# 356   tt4370382                               Cairo Time
# 1465  tt2821880                                Rangeelay
# 723   tt7870578                       Girls vs Gangsters
# 614   tt7509586                                Explosion
# 1805  tt8331988                          The Chambermaid
# 962   tt3195742             Journey to the South Pacific
# 622   tt4892714                 Fall in Love Like a Star
# 667   tt5882704                        For a Few Bullets
# 1070  tt4572856                        Let's Get Married
# 1351  tt6271528                                      Oro
# 1346  tt4819544                                 Only You
# 176   tt5792490  Antonio Lopez 1970: Sex Fashion & Disco
# 70    tt5093754                     A Melody to Remember
# 264   tt6370266                          Bending the Arc
# 1360  tt7037566                            Our President
# 2051  tt5515022            The New Year's Eve of Old Lee
# 1188  tt2713406                                 Meerkats
# 316   tt8052198                                   Bonsai
# 1018  tt2086865                                   Kisses
# 1646  tt8851262                             Spring Fever
# 1819  tt6274746                              The Concert
# 2383  tt6786720                               Wild Grass
#
#                                original_title  start_year  runtime_minutes  \
# 1981                        The King's Speech        2010           118.00
# 765            Guardians of the Galaxy Vol. 2        2017           136.00
# 1653  Star Wars: Episode VIII - The Last Jedi        2017           152.00
# 462                      Crazy, Stupid, Love.        2011           118.00
# 1217     Mission: Impossible - Ghost Protocol        2011           132.00
# 628                                 Furious 6        2013           130.00
# 1542              Scott Pilgrim vs. the World        2010           112.00
# 1218       Mission: Impossible - Rogue Nation        2015           131.00
# 1928                    The Hangover Part III        2013           100.00
# 1439      Prince of Persia: The Sands of Time        2010           116.00
# 1952                                   Jagten        2012           115.00
# 1216            Mission: Impossible - Fallout        2018           147.00
# 1435                           Predestination        2014            97.00
# 855                          I Am Number Four        2011           111.00
# 1647                                      Spy        2015           119.00
# 84                    Jodaeiye Nader az Simin        2011           123.00
# 460                          Cowboys & Aliens        2011           119.00
# 1822                          The Conjuring 2        2016           134.00
# 545                             Don't Breathe        2016            88.00
# 2104                             Serbuan maut        2011           101.00
# 404                                      Chef        2014           114.00
# 2389                               Wind River        2017           107.00
# 193                          Assassin's Creed        2016           115.00
# 1937                   The Hitman's Bodyguard        2017           118.00
# 71          A Million Ways to Die in the West        2014           116.00
# 369                         Captain Fantastic        2016           118.00
# 358                      Call Me by Your Name        2017           132.00
# 2384                         Relatos salvajes        2014           122.00
# 1830                          The Danish Girl        2015           119.00
# 593                                     Enemy        2013            91.00
# ...                                       ...         ...              ...
# 1263                                    Muran        2011           103.00
# 1038                                 Ladrones        2015            97.00
# 341                          Buddies in India        2017            99.00
# 850                           Husbands in Goa        2012           140.00
# 1060                                Odcházení        2011            94.00
# 550                      Bao dao shuang xiong        2012            87.00
# 1979                     The King's Case Note        2017           114.00
# 982                                   Kaptaan        2016           142.00
# 356                                Cairo Time        2014           110.00
# 1465                                Rangeelay        2013           129.00
# 723                                  Gui mi 2        2018           120.00
# 614                               Yin bao zhe        2017           106.00
# 1805                             La camarista        2018           102.00
# 962              Journey to the South Pacific        2013            40.00
# 622                        Peng ran xing dong        2015            98.00
# 667      Kuai Shou Qiang Shou Kuai Qiang Shou        2016           115.00
# 1070                       Zan men jie hun ba        2015           127.00
# 1351                                      Oro        2016           110.00
# 1346                      Ming zhong zhu ding        2015           114.00
# 176   Antonio Lopez 1970: Sex Fashion & Disco        2017            95.00
# 70                            Op-pa saeng-gak        2016           124.00
# 264                           Bending the Arc        2017           102.00
# 1360                            Our President        2017           119.00
# 2051                             Guo nian hao        2016           106.00
# 1188                                 Meerkats        2011            40.00
# 316                                    Bonsai        2018           102.00
# 1018                                   Kisses        2011           121.00
# 1646                             Spring Fever        2019              nan
# 1819                              The Concert        2017              nan
# 2383                               Wild Grass        2017           107.00
#
#                          genres  averagerating   numvotes   studio  \
# 1981    Biography,Drama,History           8.00 593,629.00    Wein.
# 765     Action,Adventure,Comedy           7.70 482,917.00       BV
# 1653   Action,Adventure,Fantasy           7.10 462,903.00       BV
# 462        Comedy,Drama,Romance           7.40 436,830.00       WB
# 1217  Action,Adventure,Thriller           7.40 428,142.00     Par.
# 628       Action,Crime,Thriller           7.10 346,747.00     Uni.
# 1542      Action,Comedy,Fantasy           7.50 339,338.00     Uni.
# 1218  Action,Adventure,Thriller           7.40 311,704.00     Par.
# 1928     Adventure,Comedy,Crime           5.80 270,695.00       WB
# 1439   Action,Adventure,Fantasy           6.60 254,975.00       BV
# 1952                      Drama           8.30 242,765.00    Magn.
# 1216  Action,Adventure,Thriller           7.80 233,877.00     Par.
# 1435       Drama,Mystery,Sci-Fi           7.50 225,349.00       VE
# 855     Action,Adventure,Sci-Fi           6.10 217,762.00       BV
# 1647        Action,Comedy,Crime           7.00 213,908.00      Fox
# 84               Drama,Thriller           8.30 197,684.00      SPC
# 460      Action,Sci-Fi,Thriller           6.00 195,889.00     Uni.
# 1822       Drama,Horror,Mystery           7.40 194,543.00  WB (NL)
# 545       Crime,Horror,Thriller           7.10 186,799.00     SGem
# 2104            Action,Thriller           7.60 175,968.00      SPC
# 404      Adventure,Comedy,Drama           7.30 173,270.00      ORF
# 2389        Crime,Drama,Mystery           7.70 169,007.00    Wein.
# 193     Action,Adventure,Sci-Fi           5.80 167,110.00      Fox
# 1937     Action,Comedy,Thriller           6.90 161,764.00     LG/S
# 71               Comedy,Western           6.10 160,534.00     Uni.
# 369                Comedy,Drama           7.90 159,329.00      BST
# 358               Drama,Romance           7.90 153,936.00      SPC
# 2384      Comedy,Drama,Thriller           8.10 151,123.00      SPC
# 1830    Biography,Drama,Romance           7.10 146,873.00    Focus
# 593            Mystery,Thriller           6.90 143,250.00      A24
# ...                         ...            ...        ...      ...
# 1263            Action,Thriller           6.50     244.00      UTV
# 1038                     Comedy           4.90     239.00      LGF
# 341               Action,Comedy           3.70     221.00       CL
# 850                      Comedy           3.60     204.00      UTV
# 1060               Comedy,Drama           6.00     202.00      IFC
# 550               Action,Comedy           3.60     201.00       CL
# 1979             Comedy,Mystery           6.50     188.00       CJ
# 982         Comedy,Drama,Family           6.50     174.00      UTV
# 356        Comedy,Drama,Romance           6.10     167.00      IFC
# 1465        Action,Comedy,Drama           5.00     159.00     Eros
# 723                Comedy,Drama           3.30     148.00    WGUSA
# 614             Action,Thriller           5.80     148.00       CL
# 1805                      Drama           7.10     147.00       FM
# 962                 Documentary           6.50     145.00     Imax
# 622                     Romance           5.20     144.00       CL
# 667               Action,Comedy           5.40     140.00       CL
# 1070             Comedy,Romance           5.60     140.00       CL
# 1351       Crime,Drama,Thriller           6.10     113.00     Sony
# 1346             Comedy,Romance           5.20     107.00       CL
# 176       Biography,Documentary           6.50     102.00       FM
# 70             Action,Drama,War           7.30      94.00       CJ
# 264                 Documentary           8.10      93.00     Abr.
# 1360                Documentary           5.30      82.00       CJ
# 2051                      Drama           4.60      36.00       CL
# 1188                Documentary           7.40       7.00      NGE
# 316                       Drama            nan        nan   Strand
# 1018                      Drama            nan        nan    Osci.
# 1646              Comedy,Horror            nan        nan   Strand
# 1819                     Family            nan        nan    Wein.
# 2383         Documentary,Family            nan        nan      SPC
#
#       domestic_gross foreign_gross  year  ct
# 1981  135,500,000.00     275400000  2010   1
# 765   389,800,000.00     473900000  2017   1
# 1653  620,200,000.00     712400000  2017   1
# 462    84,400,000.00      58500000  2011   1
# 1217  209,400,000.00     485300000  2011   1
# 628   238,700,000.00     550000000  2013   1
# 1542   31,500,000.00      16100000  2010   1
# 1218  195,000,000.00     487700000  2015   1
# 1928  112,200,000.00     249800000  2013   1
# 1439   90,800,000.00     245600000  2010   1
# 1952      613,000.00           NaN  2013   1
# 1216  220,200,000.00     571000000  2018   1
# 1435       68,400.00           NaN  2015   1
# 855    55,100,000.00      94800000  2011   1
# 1647  110,800,000.00     124800000  2015   1
# 84      7,100,000.00      12800000  2011   1
# 460   100,200,000.00      74600000  2011   1
# 1822  102,500,000.00     217900000  2016   1
# 545    89,200,000.00      67900000  2016   1
# 2104    4,099,999.00           NaN  2012   1
# 404    31,400,000.00      14500000  2014   1
# 2389   33,800,000.00           NaN  2017   1
# 193    54,600,000.00     186300000  2016   1
# 1937   75,500,000.00     101100000  2017   1
# 71     43,100,000.00      44100000  2014   1
# 369     5,900,000.00      16900000  2016   1
# 358    18,100,000.00      23800000  2017   1
# 2384    3,100,000.00      23900000  2015   1
# 1830   11,100,000.00      53100000  2015   1
# 593     1,000,000.00       2400000  2014   1
# ...              ...           ...   ...  ..
# 1263       30,100.00           NaN  2011   1
# 1038    3,100,000.00           NaN  2015   1
# 341       293,000.00     109300000  2017   1
# 850        10,100.00           NaN  2012   1
# 1060      176,000.00        893000  2010   1
# 550        44,800.00           NaN  2012   1
# 1979       91,000.00           NaN  2017   1
# 982       204,000.00           NaN  2016   1
# 356     1,600,000.00        391000  2010   1
# 1465      148,000.00           NaN  2013   1
# 723        37,100.00           NaN  2018   1
# 614       123,000.00           NaN  2017   1
# 1805          300.00           NaN  2015   1
# 962     7,600,000.00       6500000  2013   1
# 622       213,000.00           NaN  2015   1
# 667        30,100.00           NaN  2016   1
# 1070      463,000.00           NaN  2015   1
# 1351        5,500.00           NaN  2017   1
# 1346       61,600.00           NaN  2015   1
# 176        43,200.00         30000  2018   1
# 70         44,300.00           NaN  2016   1
# 264        21,900.00           NaN  2017   1
# 1360      507,000.00           NaN  2017   1
# 2051       25,400.00           NaN  2016   1
# 1188      778,000.00        482000  2012   1
# 316        21,300.00           NaN  2012   1
# 1018       81,700.00         15300  2010   1
# 1646       10,800.00        150000  2010   1
# 1819      658,000.00      40500000  2010   1
# 2383      404,000.00       4200000  2010   1
#
# [1292 rows x 13 columns]

# %%
#top_studios_df_and_tn.groupby('studio').count().sort_values(ascending=False, by='tconst')

# %%
top_studios_df_and_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1148 entries, 0 to 1147
# Data columns (total 18 columns):
# tconst               1148 non-null object
# primary_title        1148 non-null object
# original_title       1148 non-null object
# start_year           1148 non-null int64
# runtime_minutes      1148 non-null float64
# genres               1148 non-null object
# averagerating        1147 non-null float64
# numvotes             1147 non-null float64
# studio               1148 non-null object
# domestic_gross_x     1147 non-null float64
# foreign_gross        1002 non-null object
# year                 1148 non-null int64
# ct                   1148 non-null int64
# movie                1148 non-null object
# release_date         1148 non-null object
# production_budget    1148 non-null object
# domestic_gross_y     1148 non-null object
# worldwide_gross      1148 non-null object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 170.4+ KB

# %%
top_studios_df_and_tn.head()

# %%
top_studios_df_and_tn.info()

# %% [markdown]
# ## Convert numeric columns to floats by stripping punctuation

# %%
top_studios_df_and_tn.domestic_gross_y = top_studios_df_and_tn.domestic_gross_y.apply(lambda x: strip_punctuation_from_number_string(x)).astype(float)
top_studios_df_and_tn
# Out:
#          tconst                       primary_title  \
# 0     tt1179933                 10 Cloverfield Lane
# 1     tt1413492                           12 Strong
# 2     tt2024544                    12 Years a Slave
# 3     tt1542344                           127 Hours
# 4     tt2059171                             13 Sins
# 5     tt1272878                              2 Guns
# 6     tt1232829                      21 Jump Street
# 7     tt2294449                      22 Jump Street
# 8     tt2172934                      3 Days to Kill
# 9     tt1622547                  30 Minutes or Less
# 10    tt1335975                            47 Ronin
# 11    tt1486193                       5 Days of War
# 12    tt1306980                               50/50
# 13    tt6359956                A Bad Moms Christmas
# 14    tt1554091                       A Better Life
# 15    tt1571222                  A Dangerous Method
# 16    tt6265828                       A Ghost Story
# 17    tt1606378              A Good Day to Die Hard
# 18    tt2243537                     A Haunted House
# 19    tt2828996                   A Haunted House 2
# 20    tt2980210             A Hologram for the King
# 21    tt1440161              A Little Bit of Heaven
# 22    tt3416532                     A Monster Calls
# 23    tt2937898                 A Most Violent Year
# 24    tt1972571                   A Most Wanted Man
# 25    tt6644200                       A Quiet Place
# 26    tt7040874                      A Simple Favor
# 27    tt0763831                    A Thousand Words
# 28    tt1268799  A Very Harold & Kumar 3D Christmas
# 29    tt0365907         A Walk Among the Tombstones
# ...         ...                                 ...
# 1118  tt1235189                         Wild Target
# 1119  tt1072748                          Winchester
# 1120  tt1449283                     Winnie the Pooh
# 1121  tt1399683                       Winter's Bone
# 1122  tt2870708                     Wish I Was Here
# 1123  tt5322012                           Wish Upon
# 1124  tt2404425                       Woman in Gold
# 1125  tt1870529                     Won't Back Down
# 1126  tt2543472                              Wonder
# 1127  tt0451279                        Wonder Woman
# 1128  tt4183692                            Woodlawn
# 1129  tt0816711                         World War Z
# 1130  tt1646987                 Wrath of the Titans
# 1131  tt1772341                      Wreck-It Ralph
# 1132  tt3385516                   X-Men: Apocalypse
# 1133  tt1877832          X-Men: Days of Future Past
# 1134  tt1270798                  X-Men: First Class
# 1135  tt2178470             Yeh Jawaani Hai Deewani
# 1136  tt1302067                           Yogi Bear
# 1137  tt1414382                           You Again
# 1138  tt1182350  You Will Meet a Tall Dark Stranger
# 1139  tt1853739                         You're Next
# 1140  tt1625346                         Young Adult
# 1141  tt1240982                       Your Highness
# 1142  tt1742336                Your Sister's Sister
# 1143  tt3312830                               Youth
# 1144  tt1790885                    Zero Dark Thirty
# 1145  tt1222817                           Zookeeper
# 1146  tt1608290                         Zoolander 2
# 1147  tt2948356                            Zootopia
#
#                           original_title  start_year  runtime_minutes  \
# 0                    10 Cloverfield Lane        2016           103.00
# 1                              12 Strong        2018           130.00
# 2                       12 Years a Slave        2013           134.00
# 3                              127 Hours        2010            94.00
# 4                                13 Sins        2014            93.00
# 5                                 2 Guns        2013           109.00
# 6                         21 Jump Street        2012           109.00
# 7                         22 Jump Street        2014           112.00
# 8                         3 Days to Kill        2014           117.00
# 9                     30 Minutes or Less        2011            83.00
# 10                              47 Ronin        2013           128.00
# 11                         5 Days of War        2011           113.00
# 12                                 50/50        2011           100.00
# 13                  A Bad Moms Christmas        2017           104.00
# 14                         A Better Life        2011            98.00
# 15                    A Dangerous Method        2011            99.00
# 16                         A Ghost Story        2017            92.00
# 17                A Good Day to Die Hard        2013            98.00
# 18                       A Haunted House        2013            86.00
# 19                     A Haunted House 2        2014            86.00
# 20               A Hologram for the King        2016            98.00
# 21                A Little Bit of Heaven        2011           106.00
# 22                       A Monster Calls        2016           108.00
# 23                   A Most Violent Year        2014           125.00
# 24                     A Most Wanted Man        2014           122.00
# 25                         A Quiet Place        2018            90.00
# 26                        A Simple Favor        2018           117.00
# 27                      A Thousand Words        2012            91.00
# 28    A Very Harold & Kumar 3D Christmas        2011            90.00
# 29           A Walk Among the Tombstones        2014           114.00
# ...                                  ...         ...              ...
# 1118                         Wild Target        2010            98.00
# 1119                          Winchester        2018            99.00
# 1120                     Winnie the Pooh        2011            63.00
# 1121                       Winter's Bone        2010           100.00
# 1122                     Wish I Was Here        2014           106.00
# 1123                           Wish Upon        2017            90.00
# 1124                       Woman in Gold        2015           109.00
# 1125                     Won't Back Down        2012           121.00
# 1126                              Wonder        2017           113.00
# 1127                        Wonder Woman        2017           141.00
# 1128                            Woodlawn        2015           123.00
# 1129                         World War Z        2013           116.00
# 1130                 Wrath of the Titans        2012            99.00
# 1131                      Wreck-It Ralph        2012           101.00
# 1132                   X-Men: Apocalypse        2016           144.00
# 1133          X-Men: Days of Future Past        2014           132.00
# 1134                      X: First Class        2011           131.00
# 1135             Yeh Jawaani Hai Deewani        2013           160.00
# 1136                           Yogi Bear        2010            80.00
# 1137                           You Again        2010           105.00
# 1138  You Will Meet a Tall Dark Stranger        2010            98.00
# 1139                         You're Next        2011            95.00
# 1140                         Young Adult        2011            94.00
# 1141                       Your Highness        2011           102.00
# 1142                Your Sister's Sister        2011            90.00
# 1143                               Youth        2015           124.00
# 1144                    Zero Dark Thirty        2012           157.00
# 1145                           Zookeeper        2011           102.00
# 1146                         Zoolander 2        2016           101.00
# 1147                            Zootopia        2016           108.00
#
#                           genres  averagerating   numvotes studio  \
# 0           Drama,Horror,Mystery           7.20 260,383.00   Par.
# 1           Action,Drama,History           6.60  50,155.00     WB
# 2        Biography,Drama,History           8.10 577,301.00   FoxS
# 3      Adventure,Biography,Drama           7.60 323,949.00   FoxS
# 4                Horror,Thriller           6.30  29,550.00   RTWC
# 5            Action,Comedy,Crime           6.70 182,025.00   Uni.
# 6            Action,Comedy,Crime           7.20 477,771.00   Sony
# 7            Action,Comedy,Crime           7.00 319,504.00   Sony
# 8          Action,Drama,Thriller           6.20  81,681.00  Rela.
# 9            Action,Comedy,Crime           6.10  87,254.00   Sony
# 10        Action,Adventure,Drama           6.30 135,754.00   Uni.
# 11              Action,Drama,War           5.60  13,089.00  Anch.
# 12          Comedy,Drama,Romance           7.70 300,475.00   Sum.
# 13              Adventure,Comedy           5.50  33,056.00    STX
# 14                 Drama,Romance           7.20  14,602.00   Sum.
# 15       Biography,Drama,Romance           6.40  93,259.00    SPC
# 16         Drama,Fantasy,Romance           6.80  46,280.00    A24
# 17               Action,Thriller           5.30 188,383.00    Fox
# 18                Comedy,Fantasy           5.10  40,308.00    ORF
# 19                Comedy,Fantasy           4.70  18,085.00    ORF
# 20          Comedy,Drama,Romance           6.10  36,062.00  RAtt.
# 21          Comedy,Drama,Fantasy           6.30  26,441.00    MNE
# 22       Animation,Drama,Fantasy           7.50  70,416.00  Focus
# 23          Crime,Drama,Thriller           7.00  60,165.00    A24
# 24          Crime,Drama,Thriller           6.80  67,914.00  RAtt.
# 25           Drama,Horror,Sci-Fi           7.60 305,031.00   Par.
# 26            Comedy,Crime,Drama           6.90  83,338.00    LGF
# 27                  Comedy,Drama           5.90  36,387.00   P/DW
# 28              Adventure,Comedy           6.30  62,151.00     WB
# 29            Action,Crime,Drama           6.50 105,116.00   Uni.
# ...                          ...            ...        ...    ...
# 1118         Action,Comedy,Crime           6.80  33,915.00   Free
# 1119     Biography,Drama,Fantasy           5.40  24,351.00    LGF
# 1120  Adventure,Animation,Comedy           7.20  19,605.00     BV
# 1121               Drama,Mystery           7.20 127,751.00  RAtt.
# 1122                Comedy,Drama           6.70  34,907.00  Focus
# 1123        Drama,Fantasy,Horror           5.00  14,962.00     BG
# 1124     Biography,Drama,History           7.30  48,501.00  Wein.
# 1125                       Drama           6.40   5,915.00    Fox
# 1126                Drama,Family           8.00 111,632.00    LGF
# 1127    Action,Adventure,Fantasy           7.50 487,527.00     WB
# 1128                 Drama,Sport           6.50   6,070.00    PFR
# 1129     Action,Adventure,Horror           7.00 553,751.00   Par.
# 1130    Action,Adventure,Fantasy           5.70 172,330.00     WB
# 1131  Adventure,Animation,Comedy           7.70 344,496.00     BV
# 1132     Action,Adventure,Sci-Fi           7.00 356,556.00    Fox
# 1133     Action,Adventure,Sci-Fi           8.00 620,079.00    Fox
# 1134     Action,Adventure,Sci-Fi           7.70 608,930.00    Fox
# 1135        Comedy,Drama,Musical           7.10  33,971.00   Eros
# 1136  Adventure,Animation,Comedy           4.60  18,934.00     WB
# 1137       Comedy,Family,Romance           5.80  46,690.00     BV
# 1138        Comedy,Drama,Romance           6.30  41,608.00    SPC
# 1139        Action,Comedy,Horror           6.60  79,451.00    LGF
# 1140                Comedy,Drama           6.30  74,071.00   Par.
# 1141    Adventure,Comedy,Fantasy           5.50  92,940.00   Uni.
# 1142                Comedy,Drama           6.70  24,780.00    IFC
# 1143          Comedy,Drama,Music           7.30  64,418.00   FoxS
# 1144              Drama,Thriller           7.40 251,072.00   Sony
# 1145       Comedy,Family,Romance           5.20  52,396.00   Sony
# 1146                      Comedy           4.70  59,914.00   Par.
# 1147  Adventure,Animation,Comedy           8.00 383,446.00     BV
#
#       domestic_gross_x foreign_gross  year  ct  \
# 0        72,100,000.00      38100000  2016   1
# 1        45,800,000.00      21600000  2018   1
# 2        56,700,000.00     131100000  2013   1
# 3        18,300,000.00      42400000  2010   1
# 4            13,800.00           NaN  2014   1
# 5        75,600,000.00      56300000  2013   1
# 6       138,400,000.00      63100000  2012   1
# 7       191,700,000.00     139600000  2014   1
# 8        30,700,000.00      21900000  2014   1
# 9        37,100,000.00       3500000  2011   1
# 10       38,400,000.00     113400000  2013   1
# 11           17,500.00           NaN  2011   1
# 12       35,000,000.00       4200000  2011   1
# 13       72,100,000.00      58400000  2017   1
# 14        1,800,000.00           NaN  2011   1
# 15        5,700,000.00      21800000  2011   1
# 16        1,600,000.00           NaN  2017   1
# 17       67,300,000.00     237300000  2013   1
# 18       40,000,000.00      20100000  2013   1
# 19       17,300,000.00       6600000  2014   1
# 20        4,200,000.00           NaN  2016   1
# 21           15,400.00       1300000  2012   1
# 22        3,700,000.00      43600000  2016   1
# 23        5,700,000.00       6300000  2014   1
# 24       17,200,000.00      19000000  2014   1
# 25      188,000,000.00     152900000  2018   1
# 26       53,500,000.00      44100000  2018   1
# 27       18,500,000.00       3600000  2012   1
# 28       35,100,000.00        326000  2011   1
# 29       26,300,000.00      26900000  2014   1
# ...                ...           ...   ...  ..
# 1118        109,000.00       3300000  2010   1
# 1119     25,100,000.00           NaN  2018   1
# 1120     26,700,000.00      23200000  2011   1
# 1121      6,500,000.00       7300000  2010   1
# 1122      3,600,000.00       1900000  2014   1
# 1123     14,300,000.00           NaN  2017   1
# 1124     33,299,999.00      28300000  2015   1
# 1125      5,300,000.00           NaN  2012   1
# 1126    132,400,000.00     173500000  2017   1
# 1127    412,600,000.00     409300000  2017   1
# 1128     14,400,000.00           NaN  2015   1
# 1129    202,400,000.00     337600000  2013   1
# 1130     83,700,000.00     221600000  2012   1
# 1131    189,400,000.00     281800000  2012   1
# 1132    155,400,000.00     388500000  2016   1
# 1133    233,900,000.00     513900000  2014   1
# 1134    146,400,000.00     207200000  2011   1
# 1135      3,800,000.00           NaN  2013   1
# 1136    100,200,000.00     101300000  2010   1
# 1137     25,700,000.00       6300000  2010   1
# 1138      3,200,000.00      31000000  2010   1
# 1139     18,500,000.00           NaN  2013   1
# 1140     16,300,000.00       6600000  2011   1
# 1141     21,600,000.00       3300000  2011   1
# 1142      1,600,000.00           NaN  2012   1
# 1143      2,700,000.00           NaN  2015   1
# 1144     95,700,000.00      37100000  2012   1
# 1145     80,400,000.00      89500000  2011   1
# 1146     28,800,000.00      27900000  2016   1
# 1147    341,300,000.00     682500000  2016   1
#
#                                    movie  release_date production_budget  \
# 0                    10 Cloverfield Lane  Mar 11, 2016        $5,000,000
# 1                              12 Strong  Jan 19, 2018       $35,000,000
# 2                       12 Years a Slave  Oct 18, 2013       $20,000,000
# 3                              127 Hours   Nov 5, 2010       $18,000,000
# 4                                13 Sins  Apr 18, 2014        $4,000,000
# 5                                 2 Guns   Aug 2, 2013       $61,000,000
# 6                         21 Jump Street  Mar 16, 2012       $42,000,000
# 7                         22 Jump Street  Jun 13, 2014       $50,000,000
# 8                         3 Days to Kill  Feb 21, 2014       $28,000,000
# 9                     30 Minutes or Less  Aug 12, 2011       $28,000,000
# 10                              47 Ronin  Dec 25, 2013      $175,000,000
# 11                         5 Days of War  Aug 19, 2011       $12,000,000
# 12                                 50/50  Sep 30, 2011        $8,000,000
# 13                  A Bad Moms Christmas   Nov 1, 2017       $28,000,000
# 14                         A Better Life  Jun 24, 2011       $10,000,000
# 15                    A Dangerous Method  Nov 23, 2011       $20,000,000
# 16                         A Ghost Story   Jul 7, 2017          $100,000
# 17                A Good Day to Die Hard  Feb 14, 2013       $92,000,000
# 18                       A Haunted House  Jan 11, 2013        $2,500,000
# 19                     A Haunted House 2  Apr 18, 2014        $4,000,000
# 20               A Hologram for the King  Apr 22, 2016       $35,000,000
# 21                A Little Bit of Heaven   May 4, 2012       $12,500,000
# 22                       A Monster Calls   Jan 6, 2017       $43,000,000
# 23                   A Most Violent Year  Dec 31, 2014       $20,000,000
# 24                     A Most Wanted Man  Jul 25, 2014       $15,000,000
# 25                         A Quiet Place   Apr 6, 2018       $17,000,000
# 26                        A Simple Favor  Sep 14, 2018       $20,000,000
# 27                      A Thousand Words   Mar 9, 2012       $40,000,000
# 28    A Very Harold & Kumar 3D Christmas   Nov 4, 2011       $20,000,000
# 29           A Walk Among the Tombstones  Sep 19, 2014       $28,000,000
# ...                                  ...           ...               ...
# 1118                         Wild Target  Oct 29, 2010        $8,000,000
# 1119                          Winchester   Feb 2, 2018        $3,500,000
# 1120                     Winnie the Pooh  Jul 15, 2011       $30,000,000
# 1121                       Winter's Bone  Jun 11, 2010        $2,000,000
# 1122                     Wish I Was Here  Jul 18, 2014        $6,000,000
# 1123                           Wish Upon  Jul 14, 2017       $12,000,000
# 1124                       Woman in Gold   Apr 1, 2015       $11,000,000
# 1125                     Won't Back Down  Sep 28, 2012       $19,000,000
# 1126                              Wonder  Nov 17, 2017       $20,000,000
# 1127                        Wonder Woman   Jun 2, 2017      $150,000,000
# 1128                            Woodlawn  Oct 16, 2015       $13,000,000
# 1129                         World War Z  Jun 21, 2013      $190,000,000
# 1130                 Wrath of the Titans  Mar 30, 2012      $150,000,000
# 1131                      Wreck-It Ralph   Nov 2, 2012      $165,000,000
# 1132                   X-Men: Apocalypse  May 27, 2016      $178,000,000
# 1133          X-Men: Days of Future Past  May 23, 2014      $200,000,000
# 1134                  X-Men: First Class   Jun 3, 2011      $160,000,000
# 1135             Yeh Jawaani Hai Deewani  May 31, 2013        $8,300,000
# 1136                           Yogi Bear  Dec 17, 2010       $80,000,000
# 1137                           You Again  Sep 24, 2010       $20,000,000
# 1138  You Will Meet a Tall Dark Stranger  Sep 22, 2010       $15,000,000
# 1139                         You're Next  Aug 23, 2013        $1,000,000
# 1140                         Young Adult   Dec 9, 2011       $12,000,000
# 1141                       Your Highness   Apr 8, 2011       $50,000,000
# 1142                Your Sister's Sister  Jun 15, 2012          $120,000
# 1143                               Youth   Dec 4, 2015       $13,000,000
# 1144                    Zero Dark Thirty  Dec 19, 2012       $52,500,000
# 1145                           Zookeeper   Jul 8, 2011       $80,000,000
# 1146                         Zoolander 2  Feb 12, 2016       $50,000,000
# 1147                            Zootopia   Mar 4, 2016      $150,000,000
#
#       domestic_gross_y worldwide_gross
# 0        72,082,999.00    $108,286,422
# 1        45,819,713.00     $71,118,378
# 2        56,671,993.00    $181,025,343
# 3        18,335,230.00     $60,217,171
# 4             9,134.00         $47,552
# 5        75,612,460.00    $132,493,015
# 6       138,447,667.00    $202,812,429
# 7       191,719,337.00    $331,333,876
# 8        30,697,999.00     $38,959,900
# 9        37,053,924.00     $40,966,716
# 10       38,362,475.00    $151,716,815
# 11           17,479.00         $87,793
# 12       35,016,118.00     $41,334,735
# 13       72,110,659.00    $127,710,550
# 14        1,759,252.00      $1,884,251
# 15        5,702,083.00     $14,807,531
# 16        1,594,798.00      $2,769,782
# 17       67,349,198.00    $304,249,198
# 18       40,041,683.00     $59,922,558
# 19       17,329,487.00     $21,206,861
# 20        4,212,494.00     $11,846,010
# 21           10,011.00      $1,100,287
# 22        3,740,823.00     $46,414,530
# 23        5,749,134.00      $8,846,875
# 24       17,237,855.00     $36,068,890
# 25      188,024,361.00    $334,522,294
# 26       53,548,586.00     $97,628,717
# 27       18,450,127.00     $20,790,486
# 28       35,061,031.00     $36,265,745
# 29       26,017,685.00     $62,108,587
# ...                ...             ...
# 1118        109,338.00      $5,314,194
# 1119     25,091,816.00     $44,378,040
# 1120     26,692,846.00     $50,145,607
# 1121      6,531,503.00     $16,131,551
# 1122      3,591,299.00      $6,591,365
# 1123     14,301,505.00     $23,477,345
# 1124     33,307,793.00     $58,586,407
# 1125      5,310,554.00      $5,745,503
# 1126    132,422,809.00    $304,604,712
# 1127    412,563,408.00    $821,133,378
# 1128     14,394,097.00     $14,403,703
# 1129    202,359,711.00    $531,514,650
# 1130     83,670,083.00    $305,270,083
# 1131    189,412,677.00    $496,511,521
# 1132    155,442,489.00    $542,537,546
# 1133    233,921,534.00    $747,862,775
# 1134    146,408,305.00    $355,408,305
# 1135      3,827,466.00     $50,827,466
# 1136    100,246,011.00    $204,774,690
# 1137     25,702,053.00     $32,838,945
# 1138      3,247,816.00     $34,247,816
# 1139     18,494,006.00     $26,887,177
# 1140     16,311,571.00     $22,750,356
# 1141     21,596,445.00     $26,121,638
# 1142      1,597,486.00      $3,090,593
# 1143      2,703,296.00     $24,001,573
# 1144     95,720,716.00    $134,612,435
# 1145     80,360,866.00    $170,805,525
# 1146     28,848,693.00     $55,348,693
# 1147    341,268,248.00  $1,019,429,616
#
# [1148 rows x 18 columns]

# %%
top_studios_df_and_tn.worldwide_gross = top_studios_df_and_tn.worldwide_gross.apply(lambda x: strip_punctuation_from_number_string(x)).astype(float)

# %%
top_studios_df_and_tn.production_budget = top_studios_df_and_tn.production_budget.apply(lambda x: strip_punctuation_from_number_string(x)).astype(float)

# %% [markdown]
# ## Rename some of the columns and calculate some new columns

# %%
top_studios_df_and_tn = top_studios_df_and_tn.rename(columns={'domestic_gross_x':'bom_dom_gross',
                                                              'foreign_gross': 'bom_for_gross',
                                                              'production_budget': 'tn_prod_budget',
                                                              'domestic_gross_y':'tn_dom_gross',
                                                              'worldwide_gross': 'tn_world_gross'})

# %%
top_studios_df_and_tn['tn_profit'] = top_studios_df_and_tn['tn_world_gross'] - top_studios_df_and_tn['tn_prod_budget']

# %%
top_studios_df_and_tn['tn_roi'] = top_studios_df_and_tn['tn_profit']/top_studios_df_and_tn['tn_prod_budget']

# %%
top_studios_df_and_tn = top_studios_df_and_tn.drop('movie', axis=1)

# %%
top_studios_df_and_tn.info()

# %%
top10_roi_genres = top_studios_df_and_tn.groupby('genres').mean().sort_values(ascending=False, 
                                                   by='tn_roi')['tn_roi'][:10]
top10_roi_genres.index
# Out:
# Index(['Horror,Mystery,Thriller', 'Horror', 'Adventure,Horror',
#        'Comedy,Documentary', 'Biography,Drama,Fantasy',
#        'Drama,Horror,Thriller', 'Comedy,Fantasy', 'Action,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Adventure,Drama,Fantasy'],
#       dtype='object', name='genres')

# %%
all_roi_genres = top_studios_df_and_tn.sort_values(ascending=False, by='tn_roi')[['primary_title','tn_roi','genres']][:500]
all_roi_genres['ct']=1
df_grouped = all_roi_genres.groupby('genres').count().sort_values(ascending=False, by='ct')
top_genres = df_grouped[df_grouped['ct']>2]
top_genres.shape
# Out:
# (50, 3)

# %% [markdown]
# ## Try to remap the categories into simpler ones

# %%
top_studios_df_and_tn[top_studios_df_and_tn.genres.isin(animation_genres)].groupby('genres').sum()['ct']

# %%
animation_genres = top_studios_df_and_tn[top_studios_df_and_tn.genres.str.contains('Animation')].genres.unique()
print(len(animation_genres))
animation_genres
top_studios_df_and_tn[top_studios_df_and_tn.genres.isin(animation_genres)].groupby('genres').sum()['ct']
# Out:
# 8
# genres
# Action,Adventure,Animation    13
# Action,Animation,Comedy        3
# Adventure,Animation,Comedy    61
# Adventure,Animation,Drama      1
# Adventure,Animation,Family     3
# Animation,Comedy,Drama         1
# Animation,Comedy,Family        5
# Animation,Drama,Fantasy        1
# Name: ct, dtype: int64

# %%
family_genres = top_studios_df_and_tn[(~top_studios_df_and_tn.genres.isin(animation_genres)) &
                                        (top_studios_df_and_tn.genres.str.contains('Family'))].genres.unique()
print(len(family_genres))
family_genres
top_studios_df_and_tn[top_studios_df_and_tn.genres.isin(family_genres)].groupby('genres').sum()['ct']
# Out:
# 16
# genres
# Action,Adventure,Family     5
# Action,Comedy,Family        2
# Action,Drama,Family         2
# Action,Family,Fantasy       1
# Adventure,Comedy,Family     9
# Adventure,Drama,Family      3
# Adventure,Family,Fantasy    8
# Adventure,Family,Sci-Fi     1
# Biography,Drama,Family      4
# Comedy,Drama,Family         4
# Comedy,Family               9
# Comedy,Family,Fantasy       2
# Comedy,Family,Romance       2
# Drama,Family                5
# Drama,Family,Music          1
# Drama,Family,Sport          1
# Name: ct, dtype: int64

# %% [markdown]
# 27 out of 190 genres contain the word 'Horror'

# %%
horror_genres = top_studios_df_and_tn[(~top_studios_df_and_tn.genres.isin(animation_genres)) &
                                      (~top_studios_df_and_tn.genres.isin(family_genres)) &
                                        (top_studios_df_and_tn.genres.str.contains('Horror'))].genres.unique()
len(horror_genres)
horror_df = top_studios_df_and_tn[top_studios_df_and_tn.genres.isin(horror_genres)])
# Out:
# 122

# %%
unmapped_genres = top_studios_df_and_tn[(~top_studios_df_and_tn.genres.isin(animation_genres)) &
                                        (~top_studios_df_and_tn.genres.isin(family_genres)) &
                                        (~top_studios_df_and_tn.genres.isin(horror_genres))].genres.unique()
#unmapped_genres.groupby('genres').sum()['ct']
len(unmapped_genres)
# Out:
# 139

# %%
action_genres=top_studios_df_and_tn[(top_studios_df_and_tn.genres.isin(unmapped_genres)) &
                                        ((top_studios_df_and_tn.genres.str.contains('Action')) |
                                        (top_studios_df_and_tn.genres.str.contains('Adventure')))].genres.unique()
print(len(action_genres))
action_genres
# Out:
# 60
# array(['Action,Drama,History', 'Adventure,Biography,Drama',
#        'Action,Comedy,Crime', 'Action,Drama,Thriller',
#        'Action,Adventure,Drama', 'Action,Drama,War', 'Adventure,Comedy',
#        'Action,Thriller', 'Action,Crime,Drama',
#        'Adventure,Biography,Comedy', 'Action,Mystery,Thriller',
#        'Action,Adventure,Biography', 'Action,Crime,Mystery',
#        'Action,Drama,Romance', 'Adventure,Drama,Romance',
#        'Action,Biography,Comedy', 'Action,Biography,Drama',
#        'Action,Comedy,Sci-Fi', 'Action,Adventure,Comedy',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Sci-Fi',
#        'Action,Drama', 'Action,Comedy,Drama', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Adventure,Western',
#        'Action,Crime', 'Action,Drama,Mystery', 'Action,Adventure,Mystery',
#        'Action,Drama,Fantasy', 'Action,Crime,Sci-Fi',
#        'Action,Fantasy,Thriller', 'Action,Sci-Fi', 'Action,Drama,Sci-Fi',
#        'Action,Adventure', 'Adventure,Comedy,Drama',
#        'Action,Sci-Fi,Thriller', 'Adventure,Comedy,Music',
#        'Action,Comedy,Sport', 'Action,Adventure,Crime',
#        'Adventure,Comedy,Crime', 'Adventure,Drama,Sci-Fi',
#        'Adventure,Fantasy', 'Action,Drama,Western', 'Action,Comedy',
#        'Action,Comedy,Romance', 'Adventure,Drama',
#        'Action,Biography,Crime', 'Action,Adventure,Thriller',
#        'Adventure,Comedy,Romance', 'Adventure,Comedy,Sci-Fi',
#        'Adventure,Mystery,Sci-Fi', 'Adventure,Drama,Thriller',
#        'Action,Drama,Sport', 'Adventure,Comedy,Fantasy', 'Action',
#        'Action,Mystery,Sci-Fi', 'Action,Fantasy,Western',
#        'Adventure,Crime,Drama', 'Adventure,Drama,Western'], dtype=object)

# %%
unmapped_genres = top_studios_df_and_tn[(~top_studios_df_and_tn.genres.isin(animation_genres)) &
                                        (~top_studios_df_and_tn.genres.isin(family_genres)) &
                                        (~top_studios_df_and_tn.genres.isin(action_genres)) &
                                        (~top_studios_df_and_tn.genres.isin(horror_genres))].genres.unique()
#unmapped_genres.groupby('genres').sum()['ct']
len(unmapped_genres)
s = top_studios_df_and_tn[top_studios_df_and_tn.genres.isin(unmapped_genres)].groupby('genres').sum()['ct']
s.sort_values(ascending=False)
# Out:
# genres
# Comedy,Drama,Romance        50
# Comedy,Drama                39
# Comedy                      37
# Drama                       35
# Drama,Romance               30
# Comedy,Romance              29
# Biography,Drama,History     21
# Drama,Thriller              18
# Biography,Comedy,Drama      17
# Crime,Drama,Thriller        17
# Biography,Drama             16
# Crime,Drama                 13
# Biography,Crime,Drama       11
# Crime,Drama,Mystery         10
# Comedy,Crime,Drama           9
# Comedy,Drama,Music           8
# Biography,Drama,Sport        8
# Drama,Sport                  8
# Drama,Mystery,Thriller       7
# Drama,Mystery,Sci-Fi         7
# Drama,Fantasy,Romance        7
# Biography,Drama,Thriller     7
# Comedy,Crime                 6
# Drama,Music                  6
# Biography,Drama,Romance      6
# Biography,Drama,Music        5
# Comedy,Drama,Fantasy         4
# Comedy,Fantasy               4
# Drama,Music,Romance          4
# Drama,Romance,Sci-Fi         4
#                             ..
# Drama,Sci-Fi                 2
# Drama,Sci-Fi,Thriller        2
# Comedy,Romance,Sport         2
# Drama,Thriller,War           2
# Drama,War                    2
# Mystery,Sci-Fi,Thriller      2
# Biography,Drama,War          1
# Biography,Drama,Musical      1
# Biography,Drama,Fantasy      1
# Music                        1
# Drama,Mystery                1
# Drama,Romance,War            1
# Documentary,History          1
# Comedy,Documentary           1
# Comedy,Sci-Fi                1
# Documentary,War              1
# Crime,Drama,Romance          1
# Mystery,Thriller             1
# Drama,Fantasy,Music          1
# Crime,Documentary            1
# Comedy,Sport                 1
# Drama,Fantasy,Mystery        1
# Drama,Music,Musical          1
# Comedy,Mystery,Sci-Fi        1
# Comedy,Mystery               1
# Drama,History                1
# Comedy,Drama,Sport           1
# Drama,History,Romance        1
# Comedy,Drama,History         1
# Romance,Sci-Fi,Thriller      1
# Name: ct, Length: 79, dtype: int64

# %% [markdown]
# ## Create a dataframe that just has titles from our project dataset with ROI greater than 10x multiplier
# - Print out some mean statistics on the project dataset overall vs just the 10x ROI subset

# %%
top_roi = top_studios_df_and_tn[top_studios_df_and_tn['tn_roi']>1]
top_roi_studios_df = top_studios_df_and_tn[top_studios_df_and_tn['tn_roi']>1].groupby(['studio']).sum()\
                    .sort_values(by='tn_roi', ascending=False)[:10]
print(top_roi_studios_df.index)
top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)]['tn_prod_budget'].hist(by=top_studios_df_and_tn['studio']);
#top_roi_studios_df
# Out:
# Index(['Uni.', 'WB (NL)', 'Par.', 'Fox', 'WB', 'LGF', 'Sony', 'FoxS', 'BV',
#        'Wein.'],
#       dtype='object', name='studio')

# %%
print("Mean number of votes among studios with top ROI"
      , top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)]['numvotes'].mean())
print("Mean rating among studios with top ROI"
      , top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)]['averagerating'].mean())
print("Mean worldwide_gross among studios with top ROI"
      , top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)]['tn_world_gross'].mean())
print("Mean worldwide_gross among studios for top ROI"
      , top_roi[top_roi['studio'].isin(top_roi_studios_df.index)]['tn_world_gross'].mean())
print("Mean production budget among studios with top ROI"
      , top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)]['tn_prod_budget'].mean())
print("Mean production budget among studios for top ROI films"
      , top_roi[top_roi['studio'].isin(top_roi_studios_df.index)]['tn_prod_budget'].mean())
print("\nGenres produced among studios with top ROI films:\n"
      , top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)].groupby('genres')['ct'].sum().sort_values(ascending=False))   
print("\nGenres produced among studios for top ROI films:\n"
      , top_roi[top_roi['studio'].isin(top_roi_studios_df.index)].groupby('genres')['ct'].sum().sort_values(ascending=False))
# Out:
# Mean number of votes among studios with top ROI 173839.90883190883
# Mean rating among studios with top ROI 6.491595441595434
# Mean worldwide_gross among studios with top ROI 225943997.008547
# Mean worldwide_gross among studios for top ROI 298281965.7954071
# Mean production budget among studios with top ROI 65550566.452991456
# Mean production budget among studios for top ROI films 69439243.52818371
#
# Genres produced among studios with top ROI films:
#  genres
# Adventure,Animation,Comedy    53
# Action,Adventure,Sci-Fi       41
# Comedy                        29
# Comedy,Drama,Romance          22
# Comedy,Romance                21
# Action,Comedy,Crime           21
# Comedy,Drama                  21
# Action,Adventure,Fantasy      20
# Horror,Mystery,Thriller       20
# Action,Adventure,Drama        17
# Action,Adventure,Comedy       16
# Drama,Romance                 16
# Biography,Drama,History       15
# Action,Crime,Drama            12
# Action,Crime,Thriller         11
# Biography,Comedy,Drama        11
# Action,Thriller               10
# Drama                         10
# Action,Adventure,Thriller      9
# Horror,Thriller                9
# Crime,Drama,Thriller           8
# Comedy,Family                  8
# Adventure,Family,Fantasy       8
# Adventure,Comedy,Family        8
# Action,Adventure,Animation     7
# Drama,Thriller                 7
# Biography,Drama,Sport          7
# Biography,Drama                7
# Horror                         6
# Crime,Drama                    6
#                               ..
# Drama,Sci-Fi                   1
# Drama,Sci-Fi,Thriller          1
# Drama,Thriller,War             1
# Drama,War                      1
# Drama,Western                  1
# Fantasy,Horror,Mystery         1
# Horror,Sci-Fi,Thriller         1
# Mystery,Sci-Fi,Thriller        1
# Comedy,Romance,Sport           1
# Comedy,Mystery                 1
# Adventure,Comedy,Music         1
# Comedy,Music,Romance           1
# Adventure,Comedy,Romance       1
# Adventure,Comedy,Sci-Fi        1
# Adventure,Drama,Western        1
# Adventure,Mystery,Sci-Fi       1
# Animation,Comedy,Drama         1
# Biography,Comedy,Crime         1
# Biography,Drama,Fantasy        1
# Biography,Drama,Musical        1
# Mystery,Thriller               1
# Comedy,Crime,Romance           1
# Comedy,Crime,Thriller          1
# Comedy,Drama,Fantasy           1
# Comedy,Drama,History           1
# Comedy,Drama,Musical           1
# Comedy,Drama,Mystery           1
# Comedy,Drama,Sport             1
# Comedy,Fantasy,Romance         1
# Action                         1
# Name: ct, Length: 143, dtype: int64
#
# Genres produced among studios for top ROI films:
#  genres
# Adventure,Animation,Comedy    44
# Action,Adventure,Sci-Fi       36
# Comedy                        19
# Horror,Mystery,Thriller       19
# Comedy,Drama                  15
# Action,Adventure,Fantasy      15
# Comedy,Drama,Romance          14
# Comedy,Romance                14
# Action,Comedy,Crime           13
# Action,Adventure,Comedy       11
# Biography,Drama,History       11
# Action,Crime,Drama            10
# Drama,Romance                 10
# Action,Crime,Thriller          8
# Action,Adventure,Thriller      8
# Action,Adventure,Drama         7
# Horror,Thriller                7
# Action,Thriller                7
# Biography,Comedy,Drama         6
# Biography,Drama                6
# Action,Adventure,Animation     6
# Horror                         6
# Comedy,Family                  5
# Animation,Comedy,Family        5
# Action,Adventure,Crime         5
# Adventure,Comedy,Family        5
# Drama,Thriller                 5
# Drama,Horror,Mystery           5
# Action,Mystery,Thriller        5
# Biography,Drama,Sport          4
#                               ..
# Crime,Horror,Mystery           1
# Drama,Fantasy,Music            1
# Drama,History,Thriller         1
# Drama,Horror,Sci-Fi            1
# Comedy,Fantasy                 1
# Drama,Sci-Fi,Thriller          1
# Drama,War                      1
# Drama,Western                  1
# Fantasy,Horror,Mystery         1
# Horror,Sci-Fi,Thriller         1
# Mystery,Sci-Fi,Thriller        1
# Comedy,Fantasy,Horror          1
# Comedy,Family,Romance          1
# Adventure,Comedy,Music         1
# Biography,Drama,Music          1
# Adventure,Comedy,Romance       1
# Adventure,Comedy,Sci-Fi        1
# Adventure,Drama,Thriller       1
# Adventure,Drama,Western        1
# Adventure,Mystery,Sci-Fi       1
# Biography,Drama,Fantasy        1
# Mystery,Thriller               1
# Comedy,Drama,Mystery           1
# Biography,Drama,Romance        1
# Comedy,Crime,Drama             1
# Comedy,Crime,Romance           1
# Comedy,Crime,Thriller          1
# Comedy,Drama,Fantasy           1
# Comedy,Drama,History           1
# Biography,Drama,Musical        1
# Name: ct, Length: 118, dtype: int64

# %%
top_studios_df_and_tn[top_studios_df_and_tn['studio']=='Uni.'].sort_values('tn_roi', ascending=False)
# Out:
#          tconst                   primary_title  \
# 1078  tt3713166                      Unfriended
# 744   tt4972582                           Split
# 313   tt5052448                         Get Out
# 981   tt2184339                       The Purge
# 1069  tt6772950                   Truth or Dare
# 338   tt5308322                 Happy Death Day
# 587   tt1204977                           Ouija
# 1026  tt3567288                       The Visit
# 395   tt5726086         Insidious: The Last Key
# 536   tt2293640                         Minions
# 564   tt2004420                       Neighbors
# 282   tt2322441            Fifty Shades of Grey
# 324   tt6966692                      Green Book
# 215   tt3469046                 Despicable Me 3
# 817   tt3181822               The Boy Next Door
# 214   tt1690953                 Despicable Me 2
# 982   tt2975578              The Purge: Anarchy
# 983   tt4094724        The Purge: Election Year
# 995   tt2709768         The Secret Life of Pets
# 494   tt2872732                            Lucy
# 778   tt1637725                             Ted
# 868   tt6133466                 The First Purge
# 622   tt2848292                 Pitch Perfect 2
# 506   tt2023587                            Mama
# 588   tt4361050           Ouija: Origin of Evil
# 138   tt1478338                     Bridesmaids
# 717   tt3470600                            Sing
# 304   tt2820852                       Furious 7
# 213   tt1323594                   Despicable Me
# 431   tt4881806  Jurassic World: Fallen Kingdom
# ...         ...                             ...
# 1056  tt0471042                     Tower Heist
# 285   tt1213641                       First Man
# 467   tt1216492                       Leap Year
# 469   tt3569230                          Legend
# 947   tt1258972     The Man with the Iron Fists
# 824   tt1488555                   The Change-Up
# 100   tt1440129                      Battleship
# 191   tt2554274                    Crimson Peak
# 1005  tt1758810                     The Snowman
# 752   tt2080374                      Steve Jobs
# 701   tt1121096                     Seventh Son
# 165   tt1438254               Charlie St. Cloud
# 847   tt1578275                     The Dilemma
# 327   tt0947810                      Green Zone
# 1036  tt0780653                     The Wolfman
# 10    tt1335975                        47 Ronin
# 495   tt1470023                       MacGruber
# 670   tt0955308                      Robin Hood
# 551   tt1571234                  Mortal Engines
# 240   tt1462041                     Dream House
# 1092  tt1655460                      Wanderlust
# 560   tt0872230                 My Soul to Take
# 114   tt1430615                     Big Miracle
# 643   tt0790736                        R.I.P.D.
# 656   tt1053424                        Repo Men
# 1141  tt1240982                   Your Highness
# 416   tt3614530           Jem and the Holograms
# 1105  tt3289724               Welcome to Marwen
# 124   tt2717822                        Blackhat
# 148   tt3707106                      By the Sea
#
#                       original_title  start_year  runtime_minutes  \
# 1078                      Unfriended        2014            83.00
# 744                            Split        2016           117.00
# 313                          Get Out        2017           104.00
# 981                        The Purge        2013            85.00
# 1069                   Truth or Dare        2018           100.00
# 338                  Happy Death Day        2017            96.00
# 587                            Ouija        2014            89.00
# 1026                       The Visit        2015            94.00
# 395          Insidious: The Last Key        2018           103.00
# 536                          Minions        2015            91.00
# 564                        Neighbors        2014            97.00
# 282             Fifty Shades of Grey        2015           125.00
# 324                       Green Book        2018           130.00
# 215                  Despicable Me 3        2017            89.00
# 817                The Boy Next Door        2015            91.00
# 214                  Despicable Me 2        2013            98.00
# 982               The Purge: Anarchy        2014           103.00
# 983         The Purge: Election Year        2016           108.00
# 995          The Secret Life of Pets        2016            87.00
# 494                             Lucy        2014            89.00
# 778                              Ted        2012           106.00
# 868                  The First Purge        2018            98.00
# 622                  Pitch Perfect 2        2015           115.00
# 506                             Mama        2013           100.00
# 588            Ouija: Origin of Evil        2016            99.00
# 138                      Bridesmaids        2011           125.00
# 717                             Sing        2016           108.00
# 304                    Furious Seven        2015           137.00
# 213                    Despicable Me        2010            95.00
# 431   Jurassic World: Fallen Kingdom        2018           128.00
# ...                              ...         ...              ...
# 1056                     Tower Heist        2011           104.00
# 285                        First Man        2018           141.00
# 467                        Leap Year        2010           100.00
# 469                           Legend        2015           132.00
# 947      The Man with the Iron Fists        2012            95.00
# 824                    The Change-Up        2011           112.00
# 100                       Battleship        2012           131.00
# 191                     Crimson Peak        2015           119.00
# 1005                     The Snowman        2017           119.00
# 752                       Steve Jobs        2015           122.00
# 701                      Seventh Son        2014           102.00
# 165                Charlie St. Cloud        2010            99.00
# 847                      The Dilemma        2011           111.00
# 327                       Green Zone        2010           115.00
# 1036                     The Wolfman        2010           103.00
# 10                          47 Ronin        2013           128.00
# 495                        MacGruber        2010            90.00
# 670                       Robin Hood        2010           140.00
# 551                   Mortal Engines        2018           128.00
# 240                      Dream House        2011            84.00
# 1092                      Wanderlust        2012            98.00
# 560                  My Soul to Take        2010           107.00
# 114                      Big Miracle        2012           107.00
# 643                         R.I.P.D.        2013            96.00
# 656                         Repo Men        2010           111.00
# 1141                   Your Highness        2011           102.00
# 416            Jem and the Holograms        2015           118.00
# 1105               Welcome to Marwen        2018           116.00
# 124                         Blackhat        2015           133.00
# 148                       By the Sea        2015           122.00
#
#                           genres  averagerating   numvotes studio  \
# 1078     Horror,Mystery,Thriller           5.60  62,043.00   Uni.
# 744              Horror,Thriller           7.30 358,543.00   Uni.
# 313      Horror,Mystery,Thriller           7.70 400,474.00   Uni.
# 981              Horror,Thriller           5.70 183,549.00   Uni.
# 1069             Horror,Thriller           5.20  33,621.00   Uni.
# 338      Horror,Mystery,Thriller           6.50  87,132.00   Uni.
# 587      Horror,Mystery,Thriller           4.50  44,054.00   Uni.
# 1026     Horror,Mystery,Thriller           6.20 102,459.00   Uni.
# 395      Horror,Mystery,Thriller           5.70  42,154.00   Uni.
# 536   Adventure,Animation,Comedy           6.40 193,917.00   Uni.
# 564                       Comedy           6.30 266,020.00   Uni.
# 282       Drama,Romance,Thriller           4.10 279,126.00   Uni.
# 324       Biography,Comedy,Drama           8.30 204,972.00   Uni.
# 215   Adventure,Animation,Comedy           6.30  92,580.00   Uni.
# 817              Horror,Thriller           4.70  34,816.00   Uni.
# 214   Adventure,Animation,Comedy           7.40 344,230.00   Uni.
# 982         Action,Horror,Sci-Fi           6.50 126,203.00   Uni.
# 983         Action,Horror,Sci-Fi           6.00  80,254.00   Uni.
# 995   Adventure,Animation,Comedy           6.50 161,997.00   Uni.
# 494       Action,Sci-Fi,Thriller           6.40 403,194.00   Uni.
# 778               Comedy,Fantasy           6.90 538,367.00   Uni.
# 868         Action,Horror,Sci-Fi           5.10  41,741.00   Uni.
# 622                 Comedy,Music           6.40 130,692.00   Uni.
# 506              Horror,Thriller           6.20 158,487.00   Uni.
# 588         Drama,Horror,Mystery           6.10  47,099.00   Uni.
# 138               Comedy,Romance           6.80 249,501.00   Uni.
# 717      Animation,Comedy,Family           7.10 115,951.00   Uni.
# 304        Action,Crime,Thriller           7.20 335,074.00   Uni.
# 213      Animation,Comedy,Family           7.70 464,511.00   Uni.
# 431      Action,Adventure,Sci-Fi           6.20 219,125.00   Uni.
# ...                          ...            ...        ...    ...
# 1056         Action,Comedy,Crime           6.20 125,102.00   Uni.
# 285      Biography,Drama,History           7.40 120,009.00   Uni.
# 467               Comedy,Romance           6.50  86,125.00   Uni.
# 469        Biography,Crime,Drama           7.00 138,947.00   Uni.
# 947                       Action           5.40  58,185.00   Uni.
# 824               Comedy,Fantasy           6.30 155,374.00   Uni.
# 100      Action,Adventure,Sci-Fi           5.80 225,342.00   Uni.
# 191         Drama,Fantasy,Horror           6.50 119,287.00   Uni.
# 1005         Crime,Drama,Mystery           5.10  47,890.00   Uni.
# 752              Biography,Drama           7.20 138,668.00   Uni.
# 701     Action,Adventure,Fantasy           5.50  66,565.00   Uni.
# 165        Drama,Fantasy,Romance           6.50  55,016.00   Uni.
# 847                 Comedy,Drama           5.30  48,148.00   Uni.
# 327        Action,Drama,Thriller           6.80 122,132.00   Uni.
# 1036        Drama,Fantasy,Horror           5.80  97,873.00   Uni.
# 10        Action,Adventure,Drama           6.30 135,754.00   Uni.
# 495        Action,Comedy,Romance           5.50  39,782.00   Uni.
# 670       Action,Adventure,Drama           6.60 239,480.00   Uni.
# 551     Action,Adventure,Fantasy           6.10  70,193.00   Uni.
# 240       Drama,Mystery,Thriller           6.00  59,714.00   Uni.
# 1092              Comedy,Romance           5.60  69,081.00   Uni.
# 560      Horror,Mystery,Thriller           4.80  18,381.00   Uni.
# 114       Biography,Drama,Family           6.50  17,585.00   Uni.
# 643      Action,Adventure,Comedy           5.60 109,078.00   Uni.
# 656          Action,Crime,Sci-Fi           6.30  96,144.00   Uni.
# 1141    Adventure,Comedy,Fantasy           5.50  92,940.00   Uni.
# 416       Adventure,Drama,Family           4.10   6,683.00   Uni.
# 1105      Biography,Comedy,Drama           6.10   8,920.00   Uni.
# 124        Action,Crime,Thriller           5.40  48,427.00   Uni.
# 148                Drama,Romance           5.30  16,206.00   Uni.
#
#       bom_dom_gross bom_for_gross  year  ct  release_date  tn_prod_budget  \
# 1078  32,500,000.00      31600000  2015   1  Apr 17, 2015    1,000,000.00
# 744  138,300,000.00     140200000  2017   1  Jan 20, 2017    5,000,000.00
# 313  176,000,000.00      79400000  2017   1  Feb 24, 2017    5,000,000.00
# 981   64,500,000.00      24900000  2013   1   Jun 7, 2013    3,000,000.00
# 1069  41,400,000.00      53900000  2018   1  Apr 13, 2018    3,500,000.00
# 338   55,700,000.00      69800000  2017   1  Oct 13, 2017    5,000,000.00
# 587   50,900,000.00      52700000  2014   1  Oct 24, 2014    5,000,000.00
# 1026  65,200,000.00      33200000  2015   1  Sep 11, 2015    5,000,000.00
# 395   67,700,000.00     100100000  2018   1   Jan 5, 2018   10,000,000.00
# 536  336,000,000.00     823400000  2015   1  Jul 10, 2015   74,000,000.00
# 564  150,200,000.00     120500000  2014   1   May 9, 2014   18,000,000.00
# 282  166,200,000.00     404800000  2015   1  Feb 13, 2015   40,000,000.00
# 324   85,100,000.00     234700000  2018   1  Nov 16, 2018   23,000,000.00
# 215  264,600,000.00     770200000  2017   1  Jun 30, 2017   75,000,000.00
# 817   35,400,000.00      17000000  2015   1  Jan 23, 2015    4,000,000.00
# 214  368,100,000.00     602700000  2013   1   Jul 3, 2013   76,000,000.00
# 982   72,000,000.00      40000000  2014   1  Jul 18, 2014    9,000,000.00
# 983   79,200,000.00      39400000  2016   1   Jul 1, 2016   10,000,000.00
# 995  368,400,000.00     507100000  2016   1   Jul 8, 2016   75,000,000.00
# 494  126,700,000.00     336700000  2014   1  Jul 25, 2014   40,000,000.00
# 778  218,800,000.00     330600000  2012   1  Jun 29, 2012   50,000,000.00
# 868   69,500,000.00      67500000  2018   1   Jul 4, 2018   13,000,000.00
# 622  184,300,000.00     103200000  2015   1  May 15, 2015   29,000,000.00
# 506   71,600,000.00      74800000  2013   1  Jan 18, 2013   15,000,000.00
# 588   35,100,000.00      46600000  2016   1  Oct 21, 2016    9,000,000.00
# 138  169,100,000.00     119300000  2011   1  May 13, 2011   32,500,000.00
# 717  270,400,000.00     363800000  2016   1  Dec 21, 2016   75,000,000.00
# 304  353,000,000.00       1,163.0  2015   1   Apr 3, 2015  190,000,000.00
# 213  251,500,000.00     291600000  2010   1   Jul 9, 2010   69,000,000.00
# 431  417,700,000.00     891800000  2018   1  Jun 22, 2018  170,000,000.00
# ...             ...           ...   ...  ..           ...             ...
# 1056  78,000,000.00      74900000  2011   1   Nov 4, 2011   85,000,000.00
# 285   44,900,000.00      60800000  2018   1  Oct 12, 2018   60,000,000.00
# 467   25,900,000.00       6700000  2010   1   Jan 8, 2010   19,000,000.00
# 469    1,900,000.00      41100000  2015   1  Nov 20, 2015   25,000,000.00
# 947   15,600,000.00       4099999  2012   1   Nov 2, 2012   15,000,000.00
# 824   37,100,000.00      38400000  2011   1   Aug 5, 2011   52,000,000.00
# 100   65,400,000.00     237600000  2012   1  May 18, 2012  220,000,000.00
# 191   31,100,000.00      43600000  2015   1  Oct 16, 2015   55,000,000.00
# 1005   6,700,000.00      36400000  2017   1  Oct 20, 2017   35,000,000.00
# 752   17,800,000.00      16700000  2015   1   Oct 9, 2015   30,000,000.00
# 701   17,200,000.00      97000000  2015   1   Feb 6, 2015   95,000,000.00
# 165   31,200,000.00      17000000  2010   1  Jul 30, 2010   44,000,000.00
# 847   48,500,000.00      21200000  2011   1  Jan 14, 2011   70,000,000.00
# 327   35,100,000.00      59800000  2010   1  Mar 12, 2010  100,000,000.00
# 1036  62,000,000.00      77800000  2010   1  Feb 12, 2010  150,000,000.00
# 10    38,400,000.00     113400000  2013   1  Dec 25, 2013  175,000,000.00
# 495    8,500,000.00        797000  2010   1  May 21, 2010   10,000,000.00
# 670  105,300,000.00     216400000  2010   1  Nov 21, 2018   99,000,000.00
# 551   16,000,000.00      67700000  2018   1  Dec 14, 2018  100,000,000.00
# 240   21,300,000.00      17200000  2011   1  Sep 30, 2011   50,000,000.00
# 1092  17,500,000.00       4200000  2012   1  Feb 24, 2012   32,500,000.00
# 560   14,700,000.00       6200000  2010   1   Oct 8, 2010   25,000,000.00
# 114   20,200,000.00       4600000  2012   1   Feb 3, 2012   40,000,000.00
# 643   33,600,000.00      44700000  2013   1  Jul 19, 2013  130,000,000.00
# 656   13,800,000.00       4600000  2010   1  Mar 19, 2010   32,000,000.00
# 1141  21,600,000.00       3300000  2011   1   Apr 8, 2011   50,000,000.00
# 416    2,200,000.00        149000  2015   1  Oct 23, 2015    5,000,000.00
# 1105  10,800,000.00       2100000  2018   1  Dec 21, 2018   45,000,000.00
# 124    8,000,000.00      11600000  2015   1  Jan 16, 2015   70,000,000.00
# 148      538,000.00       2800000  2015   1  Nov 13, 2015   20,000,000.00
#
#        tn_dom_gross   tn_world_gross        tn_profit  tn_roi
# 1078  32,789,645.00    64,364,198.00    63,364,198.00   63.36
# 744  138,141,585.00   278,964,806.00   273,964,806.00   54.79
# 313  176,040,665.00   255,367,951.00   250,367,951.00   50.07
# 981   64,473,115.00    91,266,581.00    88,266,581.00   29.42
# 1069  41,411,015.00    95,127,344.00    91,627,344.00   26.18
# 338   55,683,845.00   125,010,260.00   120,010,260.00   24.00
# 587   50,856,010.00   103,300,632.00    98,300,632.00   19.66
# 1026  65,206,105.00    98,677,816.00    93,677,816.00   18.74
# 395   67,745,330.00   167,885,588.00   157,885,588.00   15.79
# 536  336,045,770.00 1,160,336,173.00 1,086,336,173.00   14.68
# 564  150,086,800.00   270,944,428.00   252,944,428.00   14.05
# 282  166,167,230.00   570,998,101.00   530,998,101.00   13.27
# 324   85,080,171.00   322,034,439.00   299,034,439.00   13.00
# 215  264,624,300.00 1,034,727,750.00   959,727,750.00   12.80
# 817   36,006,065.00    53,401,938.00    49,401,938.00   12.35
# 214  368,065,385.00   975,216,835.00   899,216,835.00   11.83
# 982   71,562,550.00   111,534,881.00   102,534,881.00   11.39
# 983   79,042,440.00   118,514,727.00   108,514,727.00   10.85
# 995  368,384,330.00   886,750,534.00   811,750,534.00   10.82
# 494  126,573,960.00   457,507,776.00   417,507,776.00   10.44
# 778  218,665,740.00   556,016,627.00   506,016,627.00   10.12
# 868   69,488,745.00   136,617,305.00   123,617,305.00    9.51
# 622  184,296,230.00   287,625,468.00   258,625,468.00    8.92
# 506   71,628,180.00   148,095,566.00   133,095,566.00    8.87
# 588   35,144,505.00    81,831,866.00    72,831,866.00    8.09
# 138  169,211,718.00   289,632,023.00   257,132,023.00    7.91
# 717  270,329,045.00   634,454,789.00   559,454,789.00    7.46
# 304  353,007,020.00 1,518,722,794.00 1,328,722,794.00    6.99
# 213  251,513,985.00   543,464,573.00   474,464,573.00    6.88
# 431  417,719,760.00 1,305,772,799.00 1,135,772,799.00    6.68
# ...             ...              ...              ...     ...
# 1056  78,046,570.00   150,422,946.00    65,422,946.00    0.77
# 285   44,936,545.00   105,203,825.00    45,203,825.00    0.75
# 467   25,918,920.00    32,618,920.00    13,618,920.00    0.72
# 469    1,872,994.00    42,425,450.00    17,425,450.00    0.70
# 947   15,634,090.00    22,018,988.00     7,018,988.00    0.47
# 824   37,243,418.00    75,997,067.00    23,997,067.00    0.46
# 100   65,233,400.00   313,477,717.00    93,477,717.00    0.42
# 191   31,090,320.00    74,966,854.00    19,966,854.00    0.36
# 1005   6,670,765.00    43,226,146.00     8,226,146.00    0.24
# 752   17,766,658.00    35,579,007.00     5,579,007.00    0.19
# 701   17,725,785.00   108,874,967.00    13,874,967.00    0.15
# 165   31,206,263.00    48,478,084.00     4,478,084.00    0.10
# 847   48,475,290.00    70,546,865.00       546,865.00    0.01
# 327   35,497,337.00    97,523,020.00    -2,476,980.00   -0.02
# 1036  62,189,884.00   142,634,358.00    -7,365,642.00   -0.05
# 10    38,362,475.00   151,716,815.00   -23,283,185.00   -0.13
# 495    8,525,600.00     8,629,895.00    -1,370,105.00   -0.14
# 670   30,824,628.00    84,747,441.00   -14,252,559.00   -0.14
# 551   15,951,040.00    85,287,417.00   -14,712,583.00   -0.15
# 240   21,302,340.00    41,642,166.00    -8,357,834.00   -0.17
# 1092  17,288,155.00    24,159,934.00    -8,340,066.00   -0.26
# 560   14,744,435.00    16,727,470.00    -8,272,530.00   -0.33
# 114   20,157,300.00    25,268,680.00   -14,731,320.00   -0.37
# 643   33,618,855.00    79,076,678.00   -50,923,322.00   -0.39
# 656   13,942,007.00    18,195,238.00   -13,804,762.00   -0.43
# 1141  21,596,445.00    26,121,638.00   -23,878,362.00   -0.48
# 416    2,184,640.00     2,368,937.00    -2,631,063.00   -0.53
# 1105  10,763,520.00    12,874,922.00   -32,125,078.00   -0.71
# 124    8,005,980.00    19,665,004.00   -50,334,996.00   -0.72
# 148      538,460.00     3,727,746.00   -16,272,254.00   -0.81
#
# [115 rows x 19 columns]

# %%
top_studios_df_and_tn[top_studios_df_and_tn['studio']
                      .isin(top_roi_studios_df.index)].groupby('studio')['ct'].sum().sort_values(ascending=False)
# Out:
# studio
# Uni.       115
# Fox        106
# WB          97
# BV          70
# Sony        69
# Par.        69
# LGF         55
# FoxS        45
# Wein.       39
# WB (NL)     37
# Name: ct, dtype: int64

# %%
top_roi[top_roi['studio']
        .isin(top_roi_studios_df.index)].groupby('studio')['ct'].sum().sort_values(ascending=False)
# Out:
# studio
# Uni.       85
# Fox        77
# Sony       55
# WB         53
# Par.       49
# BV         47
# LGF        36
# WB (NL)    28
# Wein.      27
# FoxS       22
# Name: ct, dtype: int64

# %%
all_prod_budgets = top_studios_df_and_tn[top_studios_df_and_tn['studio']
                      .isin(top_roi_studios_df.index)].groupby('studio')['tn_prod_budget'].sum().sort_values(ascending=False)
all_prod_budgets
# Out:
# studio
# BV        9,334,800,000.00
# WB        8,059,000,000.00
# Fox       7,497,000,000.00
# Uni.      6,362,700,000.00
# Sony      4,844,500,000.00
# Par.      4,517,000,000.00
# WB (NL)   2,148,600,000.00
# LGF       1,964,887,650.00
# Wein.       796,100,000.00
# FoxS        491,910,000.00
# Name: tn_prod_budget, dtype: float64

# %%
all_prod_budgets_avg = top_studios_df_and_tn[top_studios_df_and_tn['studio']
                      .isin(top_roi_studios_df.index)].groupby('studio')['tn_prod_budget'].mean().sort_values(ascending=False)
all_prod_budgets_avg
# Out:
# studio
# BV        133,354,285.71
# WB         83,082,474.23
# Fox        70,726,415.09
# Sony       70,210,144.93
# Par.       65,463,768.12
# WB (NL)    58,070,270.27
# Uni.       55,327,826.09
# LGF        35,725,230.00
# Wein.      20,412,820.51
# FoxS       10,931,333.33
# Name: tn_prod_budget, dtype: float64

# %%
top_roi[top_roi['studio']
        .isin(top_roi_studios_df.index)].groupby('studio')['tn_prod_budget'].mean().sort_values(ascending=False)
# Out:
# studio
# BV        147,582,978.72
# WB         93,679,245.28
# Fox        78,961,038.96
# Sony       71,936,363.64
# Par.       65,795,918.37
# WB (NL)    58,450,000.00
# Uni.       52,049,411.76
# LGF        36,396,879.17
# Wein.      18,540,740.74
# FoxS       10,355,000.00
# Name: tn_prod_budget, dtype: float64

# %%
all_world_gross = top_studios_df_and_tn[top_studios_df_and_tn['studio']
                      .isin(top_roi_studios_df.index)].groupby('studio')['tn_world_gross'].sum().sort_values(ascending=False)
all_world_gross
# Out:
# studio
# BV        33,005,492,430.00
# Uni.      26,983,322,957.00
# Fox       25,970,716,879.00
# WB        21,964,047,930.00
# Sony      16,935,293,274.00
# Par.      13,733,109,035.00
# WB (NL)    8,540,864,247.00
# LGF        6,599,606,161.00
# Wein.      2,738,049,893.00
# FoxS       2,142,183,094.00
# Name: tn_world_gross, dtype: float64

# %%
all_world_gross_avg = top_studios_df_and_tn[top_studios_df_and_tn['studio']
                      .isin(top_roi_studios_df.index)].groupby('studio')['tn_world_gross'].mean().sort_values(ascending=False)
all_world_gross_avg
# Out:
# studio
# BV        471,507,034.71
# Sony      245,439,032.96
# Fox       245,006,763.01
# Uni.      234,637,590.93
# WB (NL)   230,834,168.84
# WB        226,433,483.81
# Par.      199,030,565.72
# LGF       119,992,839.29
# Wein.      70,206,407.51
# FoxS       47,604,068.76
# Name: tn_world_gross, dtype: float64

# %%
top_roi_world_gross = top_roi[top_roi['studio']
        .isin(top_roi_studios_df.index)].groupby('studio')['tn_world_gross'].sum().sort_values(ascending=False)
top_roi_world_gross
# Out:
# studio
# BV        30,063,090,690.00
# Uni.      25,019,118,762.00
# Fox       23,871,996,093.00
# WB        18,046,196,255.00
# Sony      15,607,144,392.00
# Par.      12,044,603,961.00
# WB (NL)    7,986,136,144.00
# LGF        5,885,657,918.00
# Wein.      2,507,084,056.00
# FoxS       1,846,033,345.00
# Name: tn_world_gross, dtype: float64

# %%
top_roi_world_gross_avg = top_roi[top_roi['studio']
        .isin(top_roi_studios_df.index)].groupby('studio')['tn_world_gross'].mean().sort_values(ascending=False)
top_roi_world_gross_avg
# Out:
# studio
# BV        639,640,227.45
# WB        340,494,268.96
# Fox       310,025,923.29
# Uni.      294,342,573.67
# WB (NL)   285,219,148.00
# Sony      283,766,261.67
# Par.      245,808,244.10
# LGF       163,490,497.72
# Wein.      92,854,965.04
# FoxS       83,910,606.59
# Name: tn_world_gross, dtype: float64

# %%
top_studios_df_and_tn[top_studios_df_and_tn['studio'].isin(top_roi_studios_df.index)].groupby('studio')['averagerating'].mean()
# Out:
# studio
# FD        6.30
# FoxS      6.88
# LG/S      6.44
# LGF       6.33
# Par.      6.37
# TriS      6.67
# Uni.      6.23
# WB        6.58
# WB (NL)   6.27
# Wein.     7.04
# Name: averagerating, dtype: float64

# %%
top_roi[top_roi['studio']
        .isin(top_roi_studios_df.index)].groupby('studio')['averagerating'].mean().sort_values(ascending=False)
# Out:
# studio
# BV        7.32
# Wein.     7.26
# FoxS      7.20
# WB        6.77
# Fox       6.54
# LGF       6.46
# Par.      6.41
# WB (NL)   6.39
# Uni.      6.32
# Sony      6.28
# Name: averagerating, dtype: float64

# %%
top_studios_df_and_tn[top_studios_df_and_tn['studio']
                      .isin(top_roi_studios_df.index)].groupby('studio')['numvotes'].mean().sort_values(ascending=False)
# Out:
# studio
# BV        248,198.91
# WB        214,230.29
# Par.      204,980.86
# Fox       164,946.90
# WB (NL)   160,683.46
# Sony      160,329.14
# Wein.     149,655.33
# Uni.      142,804.81
# LGF       139,014.60
# FoxS      118,675.36
# Name: numvotes, dtype: float64

# %%
top_roi[top_roi['studio']
        .isin(top_roi_studios_df.index)].groupby('studio')['numvotes'].mean().sort_values(ascending=False)
# Out:
# studio
# BV        333,371.77
# WB        299,775.06
# Par.      256,377.04
# Fox       201,457.47
# Wein.     197,071.89
# WB (NL)   191,490.07
# FoxS      184,671.45
# Sony      176,138.45
# LGF       172,274.39
# Uni.      162,229.67
# Name: numvotes, dtype: float64

# %%
top_studios_df_and_tn.shape
# Out:
# (1148, 19)

# %%
studio_list = ['Universal (Uni.)', '20th Century Fox (Fox)', 'Warner Brothers (WB)',
               'Buena Vista Pictures/Disney (BV)', 'Sony/Columbia Pictures (Sony)', 
               'Paramount Pictures (Par.)', 'Lionsgate Films (LGF)', 'Fox Searchlight (FoxS)',
               'Weinstein (Wein.)', 'Warner Brothers/New Line (WB (NL))']

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(2, 2, 1)
ax.bar(all_world_gross.index, all_world_gross);
ax.set_title('Worldwide Gross Total')
ax.set_ylabel('Worldwide Gross in Billions')
ax.set_xlabel('Top Studios')

#fig2 = plt.figure(figsize=(10, 6))
ax2 = fig.add_subplot(2, 2, 3)
ax2.bar(all_world_gross_avg.index, all_world_gross_avg);
ax2.set_title('Average Worldwide Gross per Title')
ax2.set_ylabel('Avg Worldwide Gross in Hundred Millions')
ax2.set_xlabel('Top Studios')

#fig3 = plt.figure(figsize=(10, 6))
ax3 = fig.add_subplot(2, 2, 2)
ax3.bar(all_prod_budgets.index, all_prod_budgets);
ax3.set_title('Production Budget Total')
ax3.set_ylabel('Production Budget in Billions')
ax3.set_xlabel('Top Studios')

#fig4 = plt.figure(figsize=(10, 6))
ax4 = fig.add_subplot(2, 2, 4)
ax4.bar(all_prod_budgets_avg.index, all_prod_budgets_avg);
ax4.set_title('Average Production Budget per Title')
ax4.set_ylabel('Avg Production Budget in Hundred Millions')
ax4.set_xlabel('Top Studios')
# Out:
# Text(0.5, 0, 'Top Studios')

# %%
df = top20_grossing_genres
fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df.domestic_gross.plot(kind='bar', color='red', ax=ax, width=width, position=1)
df.ct.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

# %%
top20_roi_genres = top_studios_df_and_tn.groupby('genres').sum() \
                              .sort_values(ascending=False, by='tn_roi')[['tn_roi','ct']][:20]
#top20_world_gross_genres.plot.bar()

df = top20_roi_genres
fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df.tn_roi.plot(kind='bar', color='red', ax=ax, width=width, position=1)
df.ct.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

# %%
top_studios_df_and_tn.groupby(['genres']).mean()\
    .sort_values(ascending=False, by='tn_roi')[['tn_roi']][:20].unstack().plot.bar();

# %%
top_studios_df_and_tn.describe()
# Out:
#        start_year  runtime_minutes  averagerating     numvotes  bom_dom_gross  \
# count    1,148.00         1,148.00       1,147.00     1,147.00       1,147.00
# mean     2,013.58           109.42           6.48   138,201.23  63,591,248.90
# std          2.51            17.69           0.93   172,391.22  87,059,659.61
# min      2,010.00            41.00           1.60        10.00       1,000.00
# 25%      2,011.00            97.00           5.90    34,672.50   9,450,000.00
# 50%      2,013.00           106.00           6.50    80,510.00  35,100,000.00
# 75%      2,016.00           119.00           7.10   167,799.00  78,000,000.00
# max      2,018.00           180.00           8.80 1,841,066.00 700,100,000.00
#
#           year       ct  tn_prod_budget   tn_dom_gross   tn_world_gross  \
# count 1,148.00 1,148.00        1,148.00       1,148.00         1,148.00
# mean  2,013.66     1.00   49,016,459.08  63,716,244.33   160,541,525.35
# std       2.51     0.00   57,026,970.19  87,001,538.98   241,898,479.10
# min   2,010.00     1.00       50,000.00           0.00             0.00
# 25%   2,011.00     1.00   11,000,000.00   9,616,762.75    20,772,390.50
# 50%   2,014.00     1.00   28,000,000.00  35,353,255.50    70,149,902.50
# 75%   2,016.00     1.00   60,000,000.00  78,226,424.00   182,325,247.00
# max   2,018.00     1.00  410,600,000.00 700,059,566.00 2,048,134,200.00
#
#              tn_profit   tn_roi
# count         1,148.00 1,148.00
# mean    111,525,066.27     3.49
# std     200,556,776.08    13.88
# min    -110,450,242.00    -1.00
# 25%       3,618,527.00     0.22
# 50%      35,764,245.00     1.49
# 75%     124,673,507.50     3.40
# max   1,748,134,200.00   415.56

# %% [markdown]
# ## Boxplot of ROI without outliers by Genre, for the Top 10 Genres by ROI

# %%
sns.set_context('talk')

# %%
df_long = pd.melt(top_studios_df_and_tn, id_vars =['genres'], value_vars =['tn_roi'])
df_long = df_long[df_long['genres'].isin(top10_roi_genres.index)]\
    .sort_values(ascending=False, by='value')
roi_by_genre = sns.boxplot(data=df_long, x='value', y='genres', showfliers=False)
roi_by_genre.set_title('ROI by Genre');

# %%
df_long = pd.melt(top_studios_df_and_tn, id_vars =['genres'], value_vars =['tn_prod_budget'])
df_long = df_long[df_long['genres'].isin(top10_roi_genres.index)]\
    .sort_values(ascending=False, by='genres')
budget_by_genre = sns.boxplot(data=df_long, x='value', y='genres', showfliers=False)
budget_by_genre.set_title('Production Budget by Genre');

# %%
df_long = pd.melt(top_studios_df_and_tn, id_vars =['genres'], value_vars =['tn_world_gross'])
df_long = df_long[df_long['genres'].isin(top10_roi_genres.index)]\
    .sort_values(ascending=False, by='genres')
worldgross_by_genre = sns.boxplot(data=df_long, x='value', y='genres', showfliers=False)
worldgross_by_genre.set_title('World Gross by Genre');

# %%
df_long = pd.melt(top_studios_df_and_tn, id_vars =['genres'], value_vars =['averagerating'])
df_long = df_long[df_long['genres'].isin(top10_roi_genres.index)]\
    .sort_values(ascending=False, by='genres')
rating_by_genre = sns.boxplot(data=df_long, x='value', y='genres', showfliers=False)
rating_by_genre.set_title('Average Rating by Genre');

# %%
top_studios_df_and_tn[top_studios_df_and_tn['genres'].isin(top10_roi_genres.index)].shape
# Out:
# (66, 19)
